# %% [markdown]
# ### **ChatGPT MWP performance prediction**
# The emergence of large language models (LLMs) have gained much popularity in recent years, with OpenAI's GPT-3 series models being considered as the state-of-the-art. In particular, the variant of GPT-3 tuned for natural dialog, known as ChatGPT, has gathered much popular interest. However, LLMs have known performance issues,
# specifically when reasoning tasks are involved. This project aims to investigate aspects of math word problems (MWPs) that can indicate the success or failure of ChatGPT on such problems.
#
# In this notebook in particular, we attempt to predict ChatGPT's performance on specific questions in DRAW-1K using classifiers by extracting equations from ChatGPT's response.

# %% [markdown]
# ### **Download libraries**
# In order to replicate the results produced in this notebook, it is recommended to use the exact version of Python as well as the exact versions of each library.
# We first download the libraries that will be used in this notebook. We specify the exact version of each library to download.

# %%
# %%capture

# =========================================== #
#               Requirements
# ------------------------------------------- #
# - Python 3.7.9
# =========================================== #

# %pip install nltk==3.8.1
# %pip install pandas==1.3.5
# %pip install sympy==1.10.1
# %pip install plotly==5.13.0
# %pip install xgboost==1.6.2

# %pip install xlsxwriter==3.0.9
# %pip install scikit-learn==1.0.2
# %pip install beautifulsoup4==4.11.2
# %pip install torch==1.13.1
# %pip install transformers==4.27.4
# %pip install tqdm==4.64.1

# %% [markdown]
# ### **Prompts**
# - Extract the equations from your response. Output the equations in JSON in a form in a field called "equations".  The equations should be in a form that is easy for Sympy to parse. Convert all juxtaposition to its explicit form. For example, convert "3x + abc = 9" to "3 * x + a * b * c = 9"

# %% [markdown]
# ### **Load libraries**

# %%
# =========================================== #
#                Libraries
# =========================================== #

# ------------------------------------------- #
#   Python
# ------------------------------------------- #
import re
import os
import ast
import sys
import random
import threading
from time import sleep

try:
    import thread
except ImportError:
    import _thread as thread

import wordninja

# ------------------------------------------- #
#   Pandas
# ------------------------------------------- #
import pandas
pandas.options.display.max_rows = 4000

# ------------------------------------------- #
#   Plotly
# ------------------------------------------- #
import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls
import plotly.express as px

# ------------------------------------------- #
#   Sympy
# ------------------------------------------- #
from sympy.parsing.sympy_parser import parse_expr
from sympy.parsing.sympy_parser import transformations
from sympy.parsing.sympy_parser import T
from sympy import Eq
from sympy import solve

# ------------------------------------------- #
#   Sklearn
# ------------------------------------------- #
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn import metrics

from sklearn.model_selection import KFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.neural_network import MLPClassifier

from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.ensemble import StackingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB

# ------------------------------------------- #
#   Matplotlib
# ------------------------------------------- #
import matplotlib.pyplot as plt

# ------------------------------------------- #
#   XGBoost
# ------------------------------------------- #
from xgboost import XGBClassifier

# ------------------------------------------- #
#   Tensorflow
# ------------------------------------------- #
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import activations

# ------------------------------------------- #
#   Seaborn
# ------------------------------------------- #
import seaborn

# ------------------------------------------- #
#   XlsxWriter
# ------------------------------------------- #
import xlsxwriter

# ------------------------------------------- #
#   Numpy
# ------------------------------------------- #
import numpy
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.18.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ### **Constants**
# Here, we configure values required one run through of the contents in the notebook.
# This should be the only part of the notebook you would have to change from run-to-run.

# %%
RESPONSE_FILE_PATH = '../data/hwelsters__gpt-3.5-turbo__v001 (prefix__system_of_equations).jsonl'
QUESTION_FILE_PATH = '../data/draw.json'
TEST_SIZE = 0.2
RANDOM_STATE = 42
N_SPLITS = 5
VISUALIZE_DATA = True
XLSX_OUTPUT_FILE_PATH = 'sympy_predict.xlsx'

CACHED = False
canonicalized_df = None

# %% [markdown]
# ### **Set Seed for RNGs**
# We set the seed for the RNGs to ensure consistency from run-to-run

# %%
os.environ['PYTHONHASHSEED']=str(RANDOM_STATE)
os.environ['TF_CUDNN_DETERMINISTIC'] = '1'  # new flag present in tf 2.0+
random.seed(RANDOM_STATE)
numpy.random.seed(RANDOM_STATE)
tf.random.set_seed(RANDOM_STATE)

# %% [markdown]
# ### **Load data**

# %%
# =========================================== #
#                Load data
# =========================================== #

# ------------------------------------------- #
#   Functions which loads data into
#   a dataframe based on its file extension
#   Currently accepts .json, .jsonl, .csv
# ------------------------------------------- #
def load_file(path):
    split_path = os.path.splitext(path)
    file_extension = split_path[-1]

    data = pandas.DataFrame()
    if file_extension == '.json': data = pandas.read_json(path)
    if file_extension == '.jsonl': data = pandas.read_json(path, lines=True)
    if file_extension == '.csv': data = pandas.read_csv(path)

    return data


# ------------------------------------------- #
#   Helper function that loads data stored in 
#   a file at a particular file-path into a 
#   pandas dataframe, extracting only the 
#   columns specified.
# ------------------------------------------- #
def load_data(path, sample_size=5, columns=None, label=None):
    available_columns, dataframe = load_file(path, columns)
    if columns != None: available_columns = list(set(columns).intersection(available_columns))
    return dataframe[available_columns]

# %%
equations_df = load_file('../data/equations.jsonl')
final_answer_df = load_file('../data/answers.jsonl')
response_df = load_file('../data/response.jsonl')
ground_df = load_file('../data/ground.json')

display(equations_df.head(3))
display(final_answer_df.head(3))
display(response_df.head(3))
display(ground_df.head(3))
# Out:
#                 model  temperature  max_tokens           date_time  \
# 0  gpt-3.5-turbo-0301            1        2048 2023-04-13 17:24:18
# 1  gpt-3.5-turbo-0301            1        2048 2023-04-13 17:24:18
# 2  gpt-3.5-turbo-0301            1        2048 2023-04-13 17:24:19
#
#    question_number                                           question  \
# 0                8  Extract all equations from this text and canon...
# 1               16  Extract all equations from this text and canon...
# 2               45  Extract all equations from this text and canon...
#
#                                          system_text  \
# 0  Extract all equations from this text and canon...
# 1  Extract all equations from this text and canon...
# 2  Extract all equations from this text and canon...
#
#                                             response  prompt_tokens  \
# 0  {\n  "equations": [\n    "x + y = 9",\n    "10...            363
# 1  {\n    "equations": [\n        "x + 24 = faste...            464
# 2    {"equations": ["a + c = 24", "16a + 9c = 258"]}            335
#
#    completion_tokens  total_tokens
# 0                 66           429
# 1                 65           529
# 2                 23           358
#                 model  temperature  max_tokens           date_time  \
# 0  gpt-3.5-turbo-0301            1        2048 2023-04-13 17:22:11
# 1  gpt-3.5-turbo-0301            1        2048 2023-04-13 17:22:11
# 2  gpt-3.5-turbo-0301            1        2048 2023-04-13 17:22:11
#
#    question_number                                           question  \
# 0               10  Extract the final answer from this text.  Outp...
# 1                7  Extract the final answer from this text.  Outp...
# 2               18  Extract the final answer from this text.  Outp...
#
#                                          system_text  \
# 0  Extract the final answer from this text.  Outp...
# 1  Extract the final answer from this text.  Outp...
# 2  Extract the final answer from this text.  Outp...
#
#                         response  prompt_tokens  completion_tokens  \
# 0  {"answers": [1800.0, 4200.0]}            286                 15
# 1      {"answers": [10.0, 17.0]}            286                 13
# 2              {"answers":[4.0]}            280                  7
#
#    total_tokens
# 0           301
# 1           299
# 2           287
#                 model           date_time  question_number  \
# 0  gpt-3.5-turbo-0301 2023-09-03 12:52:57                1
# 1  gpt-3.5-turbo-0301 2023-09-03 12:52:57                0
# 2  gpt-3.5-turbo-0301 2023-09-03 12:53:00                3
#
#                                             question  \
# 0  A factory makes three-legged stools and four-l...
# 1  Juniors boat will go 15 miles per hour in stil...
# 2  The student-teacher ratio for Washington High ...
#
#                                             response
# 0  \n\nLet x be the number of three-legged stools...
# 1  \n\nLet's call the speed of the current 'c'. \...
# 2  \n\nTo calculate the number of students, we ne...
#                                            sQuestion       lSolutions  \
# 0  Juniors boat will go 15 miles per hour in stil...  [2.14285714286]
# 1  A factory makes three-legged stools and four-l...     [83.0, 78.0]
# 2  a bank offers two checking plans . The anywher...           [14.0]
#
#                             Template  \
# 0    [a * m + b * m = b * c - a * c]
# 1     [a * m + b * n = c, m + n = d]
# 2  [0.01 * a * m - 0.01 * b * m = c]
#
#                                        lEquations  iIndex  \
# 0                            [12*(15-x)=9*(15+x)]  397760
# 1  [student+general=161, 3*student+4*general=566]  327651
# 2                    [(.01*30)*x=(.01*22)*x+1.12]  238992
#
#                                            Alignment Equiv
# 0  [{'coeff': 'a', 'SentenceId': 1, 'Value': 9.0,...    []
# 1  [{'coeff': 'a', 'SentenceId': 0, 'Value': 3.0,...    []
# 2  [{'coeff': 'a', 'SentenceId': 1, 'Value': 30.0...    []

# %% [markdown]
# ### **Convert ChatGPT's JSON response to Dataframe**

# %%
def extract_json(text : str, question_number):
    try: 
        text = re.findall(r'\{.*\}', text, re.DOTALL)[0]
        body = ast.literal_eval(text)
        body["question_number"] = question_number
        return body
    except: return "FAILED"


e_equations_df = equations_df.apply(lambda row : extract_json(row['response'], row["question_number"]), axis=1)
e_final_answer_df = final_answer_df.apply(lambda row : extract_json(row['response'], row["question_number"]), axis=1)

e_equations_df = e_equations_df[e_equations_df != 'FAILED']
e_final_answer_df = e_final_answer_df[e_final_answer_df != 'FAILED']

e_equations_df = pandas.DataFrame(e_equations_df.to_list())
e_final_answer_df = pandas.DataFrame(e_final_answer_df.to_list())

e_response_df = response_df[["response", "question_number"]]

display(e_equations_df.head(3))
display(e_response_df.head(3))
display(e_final_answer_df.head(3))
# Out:
#                                            equations  question_number
# 0  [x + y = 9, 10y + x = 6(x + y), 10y + x = 6x +...                8
# 1  [x + 24 = faster car rate, 2x + 24 = relative ...               16
# 2                       [a + c = 24, 16a + 9c = 258]               45
#                                             response  question_number
# 0  \n\nLet x be the number of three-legged stools...                1
# 1  \n\nLet's call the speed of the current 'c'. \...                0
# 2  \n\nTo calculate the number of students, we ne...                3
#             answers  question_number
# 0  [1800.0, 4200.0]               10
# 1      [10.0, 17.0]                7
# 2             [4.0]               18

# %%
def combine(question_number):
    ground_val = ground_df.loc[question_number]["lSolutions"]
    response_val = e_response_df[e_response_df["question_number"] == question_number]
    equations_val = e_equations_df.loc[e_equations_df["question_number"] == question_number]
    final_answer_val = e_final_answer_df.loc[e_final_answer_df["question_number"] == question_number]

    if len(response_val) > 0: response_val = response_val.iloc[0]["response"]
    else: response_val = ""

    if len(equations_val) > 0: equations_val = equations_val.iloc[0]["equations"]
    else: equations_val = []

    if len(final_answer_val) > 0: final_answer_val = final_answer_val.iloc[0]["answers"]
    else: final_answer_val = []

    return {"ground_solution" : ground_val, "response" : response_val, "equations": equations_val, "answers" : final_answer_val}

combined_df = response_df.apply(lambda row : combine(row["question_number"]), axis=1).to_list()
combined_df = pandas.DataFrame(combined_df)
combined_df.head(3)
# Out:
#    ground_solution                                           response  \
# 0     [83.0, 78.0]  \n\nLet x be the number of three-legged stools...
# 1  [2.14285714286]  \n\nLet's call the speed of the current 'c'. \...
# 2         [1155.0]  \n\nTo calculate the number of students, we ne...
#
#                                            equations       answers
# 0  [x + y = 161, 3x + 4y = 566, x = 161 - y, 3(16...  [78.0, 83.0]
# 1  [speed downstream = 15 + c, speed upstream = 1...        [2.14]
# 2               [a = b x c, a = 42 x 27.5, a = 1155]      [1155.0]

# %%
# ------------------------------------------- #
#   This function standardizes ChatGPT's 
#   equations.
#   
#   e.g 'tons of hay + tons of wheat = 10'
#       --> a + b = 10
#   
#   In some cases, ChatGPT returns a
#   dict of equations
#   In this case, we just get the values or 
#   the keys of this dictionary depending on 
#   which one has an equal sign
# ------------------------------------------- #
def group_terms(terms):
    terms = terms.strip()
    while len(terms) > 0 and (str(terms[0]).isnumeric() or terms[0] == '.'): terms = terms[1:]
    if len(terms) == 0: return []
    # if terms[0] == ' ': return []
    
    split_terms = wordninja.split(terms)
    for term in split_terms: 
        if len(term) == 1: 
            return [a for a in terms]
            while "" in split_terms: split_terms.remove("")
            return split_terms

    return [terms]

def canonicalize_equations(equations):
    REPLACE_TOKEN = "[%$#%$#]"
    MATH_SYMBOLS = "+/-*=()"
    A_CODE = 97

    variable_names = set()  

    # Find all the variables names
    for equation in equations:
        for c in MATH_SYMBOLS: equation = equation.replace(c, REPLACE_TOKEN)
        equation = equation.split(REPLACE_TOKEN)
        for e in equation: variable_names = variable_names.union(set(group_terms(e)))

    # Sort the variable names from longest to shortest
    variable_names = list(variable_names)
    variable_names = sorted(variable_names, key=len, reverse=True)
    
    variable_dict = dict()
    index = 0
    for var_name in variable_names:
        variable_dict[var_name] = f"[@!#@!#@!#!@#!@#@!#!@$#%$#^#^$%$#%$!#@#{index}]"
        index += 1

    index = 0



    middle_equations = []
    for equation in equations:
        for x, y in variable_dict.items():
            equation = equation.replace(x, y)
        equation = re.sub(r'[a-z]', '', equation)
        middle_equations.append(equation)

    canonicalized_equations = []
    for equation in middle_equations:
        for x, y in variable_dict.items():
            num = re.findall(r'[0-9]+', y)[0]
            num = int(num)
            char = chr(num + A_CODE)
            equation = equation.replace(y, char)
        canonicalized_equations.append(equation.strip())

    # display("RUN")
    # display(variable_names)
    # display(middle_equations)
    return canonicalized_equations

# def canonicalize_equations(texts):  
#     # If ChatGPT did not give equations at all, return None
#     if (str(texts) == "nan"): return None

#     # CHATGPT sometimes gives equations as dictionaries rather than arrays. 
#     # As such, we do this instead
    
#     if type(texts) is dict: 
#         new_texts = []
#         for text in texts.values(): 
#             if str(text).count('=') > 0: new_texts.append(text)
#         for text in texts.keys(): 
#             if str(text).count('=') > 0: new_texts.append(text)
#         texts = new_texts

#     if type(texts) is list and len(texts) > 0:
#         new_texts = []
#         for text in texts:
#             if type(text) is dict:
#                 for t in text.values(): 
#                     if str(t).count('=') > 0: new_texts.append(t)
#                 for t in text.keys(): 
#                     if str(t).count('=') > 0: new_texts.append(t)
#             elif type(text) is str: new_texts.append(text)
#         texts = new_texts
#         # print("NEW TEXT: ", texts)
    
#     # Converts it all to a list of str
#     if type(texts) is set: texts = list(texts)
#     texts = [str(text) for text in texts]


#     A_CODE = 97
#     letters = {}
#     index = A_CODE

#     new_texts = []
#     for text in texts:
#         if type(text) is dict:
#             text = text[list(text.values())[0]]
#         new_texts.append(text)
#     texts = new_texts


#     REP = '[supadupaepicstonkifiers]'
#     for text in texts:
#         text = str(text)
#         text = text.replace('+', REP)
#         text = text.replace('-', REP)
#         text = text.replace('*', REP)
#         text = text.replace('=', REP)
#         text = text.replace('(', REP)
#         text = text.replace(')', REP)
#         text = text.replace('{', REP)
#         text = text.replace('}', REP)
#         text = text.replace(',', '')
#         text = text.replace('/', REP)
#         text = text.replace('.', REP)

#         spl = text.split(REP)

#         for text in spl:
#             text = text.strip() 
#             while len(text) > 0 and text[0].isdigit(): text = text[1:]
#             if len(text) > 0 and not text in letters.keys(): 
#                 letters[text] = chr(index)
#                 index += 1
    
#     to_return = []

#     def get_len(key):
#         return -len(key[0])

#     test_dict_list = list(letters.items())
#     test_dict_list.sort(key = get_len)

#     letters = {ele[0] : ele[1]  for ele in test_dict_list}

#     # Canonicalizes the equation variable names
#     for text in texts:
#         for swap in letters.keys():
#             text = text.replace(swap, letters[swap])
#         to_return.append(text)

#     return to_return

if not CACHED:
    canonicalized_df = combined_df.copy()
    canonicalized_df["canonicalized_equations"] = canonicalized_df["equations"].apply(lambda row : canonicalize_equations(row))
    canonicalized_df.head()

# %%
# ------------------------------------------- #
#   A function for creating a SymPy 
#   expressions
# ------------------------------------------- #
def create_expression(text):
    split_text = text.split('=')
    expression = Eq(parse_expr(split_text[0], transformations=T[:6]), parse_expr(split_text[1], transformations=T[:6]))
    return expression


def quit_function(fn_name):
    # print to stderr, unbuffered in Python 2.
    sys.stderr.flush() # Python 3 stderr is likely buffered.
    thread.interrupt_main() # raises KeyboardInterrupt

# ------------------------------------------- #
#   A function that times out functions 
#   after a certain period of time
# ------------------------------------------- #
def exit_after(s):
    '''
    use as decorator to exit process if 
    function takes longer than s seconds
    '''
    def outer(fn):
        def inner(*args, **kwargs):
            timer = threading.Timer(s, quit_function, args=[fn.__name__])
            timer.start()
            try:
                result = fn(*args, **kwargs)
            finally:
                timer.cancel()
            return result
        return inner
    return outer

# ------------------------------------------- #
#   Solves a system of equations given in
#   a list of str
# ------------------------------------------- #
@exit_after(5)
def solve_system(equations):
    text = str(equations)
    text = wordninja.split(text)

    s = set()
    for t in text:
        if len(t) > 0 and t[0].isalpha(): s.add(t)
    
    try:
        expressions = [create_expression(equation) for equation in equations][0:len(s)]
        return solve(expressions)
    except:
        return {}

if not CACHED:
    canonicalized_df["solved_ans"] = canonicalized_df.apply(lambda row : solve_system(row["canonicalized_equations"]), axis=1)
    canonicalized_df.head(5)

# %%
canonicalized_df["equations"]
# Out:
# 0      [x + y = 161, 3x + 4y = 566, x = 161 - y, 3(16...
# 1      [speed downstream = 15 + c, speed upstream = 1...
# 2                   [a = b x c, a = 42 x 27.5, a = 1155]
# 3      [Cost = 0.3x, Cost = 1.12 + 0.22x, 1.12 + 0.22...
# 4      [M - S = 11, M + U = 53, S = M - 11, M + (U + ...
# 5      [A + C = 34, 8A + 5C = 236, C = 34 - A, 8A + 5...
# 6      [Ryan's rate of work = 1 hole / 5 hours = 0.2 ...
# 7      [B + S = 27, 3S - 4B = 11, B = 27 - S, 3S - 4(...
# 8      [x + y = 9, 10y + x = 6(x + y), 10y + x = 6x +...
# 9      [x - y = 36, x + y = 62, x = y + 36, (y + 36) ...
# 10     [x + y = 6000, 0.09x + 0.11y = 624, x = 6000 -...
# 11     [1x + 2y = 2860, 2x + 1y = 2990, 2x + 4y = 572...
# 12       [x + 6 = 4x - 30, 6 = 3x - 30, 36 = 3x, x = 12]
# 13     [x = a, a + 1500 = b, Int on 9% loan = 0.09a, ...
# 14     [(0.4)*(6)=2.4, 6-2.4=3.6, (2.4+x)/6=0.5, 2.4+...
# 15     [x = volume of 1% boric acid solution, 30 - x ...
# 16     [x + 24 = faster car rate, 2x + 24 = relative ...
# 17     [x + y = 13, y = 2x + 1, x + (2x + 1) = 13, 3x...
# 18     [x + y = 2, y = 3x + 14, x + (3x + 14) = 2, 4x...
# 19     [x + y = 81, x - y = 9, 2x = 90, x = 45, x + y...
# 20          [x + 3x = 17, 4x = 17, x = 4.25, 3x = 12.75]
# 21     [x + y = 47, x - y = 5, x = y + 5, (y + 5) + y...
# 22     [Let x be the number of liters of the 10% alco...
# 23     [x + y = 140, x - y = 16, 2x = 156, x = 78, y ...
# 24     [H - 8 = 7(S - 8), H - 8 = 7S - 56, H = 7S - 4...
# 25     [x + y = 500, 0.75x + 0.50y = 300, 0.50x + 0.5...
# 26     [y = x + 10, y = 2x - 6, x + 10 = 2x - 6, x = ...
# 27                     [508 = 6x + 70, 438 = 6x, x = 73]
# 28     [time = (amount of work) / (rate of work), rat...
# 29     [Revenue = 25x, Production cost = 54,150 + 12....
# 30     [S + (S + 7) = 27, 2S + 7 = 27, 2S = 20, S + 7...
# 31     [y = x + 4, 10y + x = 3(10x + y) + 6, 10y + x ...
# 32     [0.09x + 0.08y = 770, x + y = 9000, x = 9000 -...
# 33     [x + y = 70, 0.65x + 0.30y = 31.5, x = 70 - y,...
# 34     [3x + 4.5(450 - x) = 1950, x + (450 - x) = 450...
# 35     [x = 2y + 3, x + y = 27, x = 2y + 3, (2y + 3) ...
# 36     [C = 2G, C - 9 = 5(G - 9), C - 9 = 5G - 45, 2G...
# 37     [0.05x + 0.10(5x) = 3.30, 0.05x + 0.50x = 3.30...
# 38     [300 = (b - c) * 10, b - c = 30, 350 = (b + c)...
# 39     [Mr. Herman = $125 - x, Mr. Chandra = $80 - x,...
# 40     [0.04x + 0.065(5000 - x) = 282.50, 0.04x + 325...
# 41                            [8x + 5y = -13, x + y = 1]
# 42               [x + 3x = 52, 4x = 52, x = 13, 3x = 39]
# 43     [y + x = 88, y = 5x + 10, (5x + 10) + x = 88, ...
# 44     [x + 0.04x = 1.04x, 1.04x = 1058.30, x = 1015,...
# 45     [0.2x + 0.6(10-x) = 0.28(10), 0.2x + 6 - 0.6x ...
# 46                          [a + c = 24, 16a + 9c = 258]
# 47     [distance = x km/h * 2 hours, distance = 2x km...
# 48     [x = 2y + 4, x + y = 25, 2y + 4 + y = 25, 3y +...
# 49     [Profit from first car = 0.35(y - (x - 2600)),...
# 50     [x = 2000, 4x = 8000, interest(6%) = 0.06x, in...
# 51     [0.25x + 0.5y = 18, x + y = 40, 0.5x + y = 36,...
# 52           [x + y = -42, x - y = 52, 2x = 10, y = -47]
# 53     [ratio = girls / 8, total ratio = 9 + 8, stude...
# 54     [10x + y - 27 = 10y + x, 9x - 9y = 27, x - y =...
# 55     [1 / t = r, Sally's rate of work = 1/4, John's...
# 56     [J = 6K, J+2 = 2(K+2), J+2 = 2K + 4, J = 2K + ...
# 57     [x+y=108, 0.18x+0.21y=0.1975(108), 18x+21y=197...
# 58     [x + y = 13, 2x + 7.5y ≤ 70, x = 13 - y, 2(13-...
# 59     [x = 3y, x + 20 = y + 6, 3y + 20 = y + 6, 2y =...
# 60     [r = (3/4)o, (r-4) = (1/2)(o-4) + 1, r - 4 = (...
# 61     [x = pounds of $9 coffee beans, 100 - x = poun...
# 62     [x + y = 55, y = x - 9, x + (x - 9) = 55, 2x -...
# 63          [M - 10 = W, M = 2*(M - 10), M = 20, W = 10]
# 64     [x = number of adult tickets, children's ticke...
# 65     [x + y = 70, x = 2y + 10, 2y + 10 + y = 70, 3y...
# 66     [x + y = 28, 0.05x + 0.1y = 2.6, x = 28 - y, 0...
# 67     [x = amount of water added, initial alcohol = ...
# 68     [60 * 0.20 = 12, 12 + x, 60 + x, (0.25 * (60 +...
# 69     [x + y = 429, 1x + 0.75y = 372.5, 0.75x + 0.75...
# 70     [x + y = 200, 0.35x + 0.72y = 100, y = 200 - x...
# 71     [X - 3 = 2(Y - 3), X - 3 = 2Y - 6, X = 2Y - 3,...
# 72     [x - 0.30 = cost of bag of peanuts, (x + x - 0...
# 73     [Total cost = (cost per pound of coffee 1 x nu...
# 74                                    [x = 2, 3 + x = 5]
# 75     [4 * 0.10 = 0.4, 0.4 + x = 0.2 * (4 + x), 0.4 ...
# 76     [3x + y = 14, 2x - y = 1, 5x = 15, y = 14 - 3x...
# 77     [x + y = 24, 0.4x + 0.1y = 7.2, 4x + y = 72, y...
# 78                           [x + y = 12, 15x + 3y = 96]
# 79                       [x + y = 12, 100x + 80y = 1050]
# 80     [x + y = 89, 4x + y = 155, y = 89 - x, 4x + (8...
# 81     [M = S + 9, M + 1 = 3(S + 1), S + 9 + 1 = 3(S ...
# 82     [6x + 5y = 419, 5x + 7y = 488, 42x + 35y = 293...
# 83     [x - y = 16, 3x = 9y, x = 3y, 2y = 16, y = 8, ...
# 84     [3x + 4 = (1/2)x - 1, 3x - (1/2)x = -1 - 4, (5...
# 85     [x + y = 7200, 0.08x = 0.1y, x/y = 0.1/0.08, x...
# 86     [2x + 3y = 13, x + y = 7, y = 7 - x, 2x + 3(7 ...
# 87     [150 = 10x - 10y, 2x + 2y = 150, 15 = x - y, 2...
# 88     [time = distance ÷ speed, time walking = d ÷ 4...
# 89     [x = pounds cheaper kind, 27 - x = pounds expe...
# 90     [x + y = 1000, 0.03x = amount of salt in the 3...
# 91     [x + y = 140, 15x + 10y = 1600, y = 140 - x, 1...
# 92     [x + y = 200, 0.2x + 0.7y = 100, 0.2x + 0.2y =...
# 93       [B + (B + 9) = 19, 2B + 9 = 19, 2B = 10, B = 5]
# 94     [x = amount invested in certificates of deposi...
# 95     [2/3*x + 3/4*x = 5/3, 8/12*x + 9/12*x = 5/3, 1...
# 96     [time = (amount of work) / (rate of work), Jus...
# 97     [60 = (B+S) × 3, B+S = 20, 60 = (B-S) × 12, B-...
# 98     [time = (amount of work) / (rate of work), rat...
# 99     [x + y = 107, x - y = 17, x + y + x - y = 107 ...
# 100    [x = 4y, x + 8 = 2(y + 8), 4y + 8 = 2(y + 8), ...
# 101    [10y + x = 8(x + y), 10y + x = 8x + 8y, 2y = 7...
# 102    [D + P = 850, 300D + 225P = 217500, D = 850 - ...
# 103              [y = 2x - 5, x + y = 28, y = 2(11) - 5]
# 104    [y = 4x + 2, x + y = 33, x + (4x + 2) = 33, 5x...
# 105    [p + w = 485, p - w = 275, p = 485 - w, (485 -...
# 106           [3x - 14 = x, 2x - 14 = 0, 2x = 14, x = 7]
# 107       [x = 18, 42 + x = 2(12 + x), 42 + x = 24 + 2x]
# 108    [x + y = 15, 3x = 5y - 11, y = (3x + 11)/5, 5x...
# 109    [x + 25 = Jen's age, Jen's age = 3x - 7, Jen's...
# 110    [Time = distance / speed = 2 miles / 3 mph = 2...
# 111    [x=y+4, 2x=4y+12, x=(4y+12)/2, x=2y+6, y+4=2y+...
# 112    [x = amount of Spanish peanuts, 10 + x = total...
# 113    [3x + 2y = 8, 2x - y = 3, y = 2x - 3, 3x + 4x ...
# 114    [work = rate x time, 20,000 = 40x + 35y, 40,00...
# 115    [d1 + d2 = 1800, t1 + t2 ≤ 20, d1 = 70t1, d2 =...
# 116    [48000 / 1800 = 26.67, 48000 / 21 = 2285.71, 1...
# 117    [340 + x, 340 - x, 200 / (340 + x) = 140 / (34...
# 118    [y = 3x + 4, 2y - 3x = 32, 2(3x + 4) - 3x = 32...
# 119    [x + y = 56, 1/3 x + 1/4 y = 16, x = 56 - y, 1...
# 120    [0.15x + 0.30(6 - x) = 0.20(6), 0.15x + 1.8 - ...
# 121    [x + y = 350, time_1 = x / 1.6, time_2 = y / 1...
# 122    [q = 2d + 7, 0.25q + 0.10d = 10.15, 0.50d + 1....
# 123    [140 = (x + y) × 0.8, x + y = 175, 140 = (x - ...
# 124     [x + (x - 5) = 33, 2x - 5 = 33, 2x = 38, x = 19]
# 125      [L = P + 2, 0.37L + 0.88P = 4.49, P = 3, L = 5]
# 126    [0.2x + 0.05(8) = 0.1(x + 8), 0.2x + 0.4 = 0.1...
# 127    [0.74x + 0.53(42 - x) = 0.63(42), 0.74x + 22.2...
# 128    [180 - w = (d)/(t), 3(180 - w) = d, 180 + w = ...
# 129    [distance = speed × time, d1 = 12 km/h × (some...
# 130    [distance = rate x time, rate = distance ÷ tim...
# 131    [1/Ta + 1/Tb + 1/Tc = 1/T, 1/130 + 1/100 + 1/1...
# 132    [36 + x = 3(8 + x), 36 + x = 24 + 3x, 2x = 12,...
# 133    [x + y = 42, x + 2y = 57, x = 42 - y, 42 + y =...
# 134               [19 + 4x = 166 - 3x, 7x = 147, x = 21]
# 135    [0.37x + 0.20(20 - x) = 7.06, 0.37x + 4 - 0.20...
# 136    [distance = speed x time, 16 = 3x * (40/60), 1...
# 137    [y = 4x, x + y = 95, x + 4x = 95, 5x = 95, y =...
# 138    [A = 4B, A + B - 10 = 45, A + B = 55, 4B + B =...
# 139    [interest = (principal x rate x time), 0.02x, ...
# 140    [Time = (Amount of Work) / (Rate of Work), Tot...
# 141    [x + y = 400, 0.7x + 0.4y = 244, y = 400 - x, ...
# 142    [y = x + 5, x + 2y = 22, x + 2(y) = 22, x + 2(...
# 143    [y = 2x + 7, x + y = 25, 3x + 7 = 25, x = 6, y...
# 144    [x + y = 12, 0.05x + 0.20y = 1.8, 0.05x + 0.05...
# 145    [a + s = 529, 25a + 15s = 9745, a = 529 - s, 2...
# 146    [180 + x = effective_speed_with_wind, 180 - x ...
# 147    [B + N = 91, B - X = 2(N - X), B = 2N - X, 3N ...
# 148    [x + y = 18, 3x + 4y = 56, x = 18 - y, 3(18 - ...
# 149     [3x - 8 = x + 4, 3x - x = 4 + 8, 2x = 12, x = 6]
# 150    [capacity of tank = 90, rate of filling by pip...
# 151    [12 - x, x(45/minute) + (12 - x)(35/minute) = ...
# 152                [x + 0.8x = 252, 1.8x = 252, x = 140]
# 153    [c + a = 754, 1.5c + 2.25a = 1422, c = 754 - a...
# 154              [x + 5x = 96, 6x = 96, x = 16, 5x = 80]
# 155    [x = y + 2, 2x = 3y - 4, y = x - 2, 2x = 3(x -...
# 156    [x = rate of current, 20 + x = rate of rowing ...
# 157                [x + 9 = 16, (x + 9) / 16 = 1, x = 7]
# 158    [x, 0.05x, Total earnings = $1000 + 0.05x, $10...
# 159                       [4x = x + 33, 3x = 33, x = 11]
# 160    [larger tank = 2x + 9, x + (2x + 9) = 54, 3x +...
# 161    [4x = Distance traveled by slower car, 4x + 32...
# 162    [2x + y = 37, x + 2y + 5 = 37, x + 2y = 32, 2(...
# 163         [p + w = 158, p - w = 112, 2p = 270, w = 23]
# 164    [3w + 3r = 17.70, 2w + 3r = 15.54, -6w - 9r = ...
# 165    [b - c = (distance upstream) / (time upstream)...
# 166    [30x + 20(7-x) = 160, 30x + 140 - 20x = 160, 1...
# 167    [K + 5 = A, K + 10 = 5 + (K + 10) - A, K + 10 ...
# 168    [0.4x + 0.9(140 - x) = 0.8(140), 0.4x + 126 - ...
# 169    [x + y = 850, 300x + 225y = 217500, 300x + 225...
# 170    [s = v1 + v2, s = 125, d = s x t, t = d / s, d...
# 171    [x + y = 43, x - y = 12, 2x = 55, x = 27.5, 27...
# 172                   [2x - 10 = x + 2, 2x - x = 10 + 2]
# 173    [y = 4x + 2, x + y = 67, y - 2 = 4x, x = (y - ...
# 174    [x + y = 33,000, 0.04x + 0.0225y = 970, y = 33...
# 175    [x / 7 + (8 - x) / 3 = 2, x / 7 = t1, (8 - x) ...
# 176    [y = x + 5, x + y = 71, x + (x + 5) = 71, 2x +...
# 177    [x + (255 - x) = 255, x - (255 - x) = 45, 2x -...
# 178     [x + (x + 4) = 60, 2x + 4 = 60, 2x = 56, x = 28]
# 179    [x + y = 80, y = 3x - 9, x + (3x - 9) = 80, 4x...
# 180    [x + y = 9000, 0.09x + 0.08y = 770, y = 9000 -...
# 181    [220(0.5) + x(1) = (220 + x)(0.75), 110 + x = ...
# 182                             [x + y = 57, x = 4y - 3]
# 183                   [x + 13 = 1.5x, 0.5x = 13, x = 26]
# 184    [0.20 (250 + x) = 20 + x, 50 + 0.2x = 20 + x, ...
# 185    [b + e = 90, 12b + 16e = 1350, b = 90 - e, 12(...
# 186    [d = 45t, d = 55(t - 4), 45t = 55(t - 4), 45t ...
# 187    [x + y = 67, y = x - 21, x + (x-21) = 67, 2x -...
# 188    [J = T - 4, J + T = 41, (T - 4) + T = 41, 2T -...
# 189    [x = number of years from now to achieve mothe...
# 190    [20 miles/hr = 32.18688 km/hr, distance A + di...
# 191    [6s + 9n = 10500, s = n + 250, 6(n+250) + 9n =...
# 192    [x + y = 50,000, 0.08x + 0.085y = 4,120, x = 5...
# 193    [(p - w) x 30 = 6030, (p + w) x 30 = 6750, p -...
# 194    [x + y = 75, y = 2x - 3, x + (2x - 3) = 75, 3x...
# 195    [d = rt, d = 24t, d = 18(7 - t), t + (7 - t) =...
# 196    [y - x = 14, x + y = 56, y = x + 14, x + (x + ...
# 197    [time = d / 300, time = d / 500, d / 300 + d /...
# 198    [16 + x = 3(2 + x), 16 + x = 6 + 3x, 16 = 6 + ...
# 199    [0.04x + 0.0225(33,000 - x) = 970, 0.04x + 742...
# 200    [distance = rate x time, D = 55t - 40t, D = 15...
# 201    [y - x = 37, y = 6x - 3, (6x - 3) - x = 37, 5x...
# 202                         [x + y = 21, 5x + 10y = 165]
# 203    [0.1x = 20, 0.075s + c = 20, c + s = 200, s = ...
# 204    [x = number of years ago when the father was s...
# 205    [x = 8, x + 7 = 15, 4x + 2(x + 7) = 62, 4x + 2...
# 206    [D + 0.2D = 792, 1.2D = 792, D = 660, DD = 1.2...
# 207    [x = years, Ricky's age now: Ricky = 10, Fathe...
# 208    [y = x + 4, 3x + 2y = 43, 3x + 2(x + 4) = 43, ...
# 209    [x + y = 90, 12x + 16y = 1350, y = 90 - x, 12x...
# 210    [x = son's age, 5x = father's age, x + 15 = so...
# 211    [(19L x 30%) + (x liters x 80%) = (19L - x lit...
# 212    [L = 2J + 3, (L + 5) + (J + 5) = 28, J = (L - ...
# 213    [0.08x + 0.05(8000 - x) = 490, 0.08x + 400 - 0...
# 214              [a + b = 9, ba = ab + 27, 10b - 9 = 27]
# 215                                                   []
# 216                        [x + 3x = 28, 4x = 28, x = 7]
# 217    [F = 100/10, D = 100/20, Effective rate of fil...
# 218    [B + 69, B + (B + 69) = 345, 2B + 69 = 345, 2B...
# 219    [3/2 = 1.5 = 2x, x = 1.5/2 = 0.75, 3x = 2.25y,...
# 220    [distance = x * 6, distance = (x+5) * 6, 6x + ...
# 221          [x + 4 = 2(x - 6), x + 4 = 2x - 12, x = 16]
# 222    [x + (3x + 9) = 53, 4x + 9 = 53, 4x = 44, x = 11]
# 223    [distance = rate x time, distance A = 60t, dis...
# 224    [B = D - 3, B + D = 53, (D - 3) + D = 53, 2D -...
# 225    [1/Ts + 1/Tm = 1/Tb, Ts = 5, Tm = 3, 1/Ts = 1/...
# 226    [Jose's rate of painting the room: 1 room / 2 ...
# 227    [x = 0.14y, y = 25000 - x, 0.14x + (4000 - 0.1...
# 228            [x + y = 12, 5x + 10y = 100, x + 2y = 20]
# 229    [y = x + 7, x + y = 33, 2x + 7 = 33, x = 13, y...
# 230    [x + y = 45, 2x = y + 3, y = 45 - x, 2x = (45 ...
# 231    [y - x = 10, 8x + 40 = 3y - 10, y = x + 10, 8x...
# 232    [x + y = 400, 3.5x + 4y = 1458, y = 400 - x, 3...
# 233    [x + y = 3000, 0.1x + 0.08y = 256, 10x + 8y = ...
# 234    [x + y = 20000, 0.01x + 0.03y = 450, x = 20000...
# 235    [0.16x + 0.08(320 - x) = 0.14(320), 0.16x + 25...
# 236    [x + (x + 24) = 56, 2x + 24 = 56, 2x = 32, x +...
# 237    [0.2 * 90 = 18, 18 / (90 + x) = 15/100, 18 * 1...
# 238    [n + d = 30, 0.05n + 0.10d = 1.90, n = 30 - d,...
# 239          [x - y = -11, x + y = -3, 2x = -14, y = -4]
# 240    [x + y = 60, 0.3x + 0.6y = 30, 0.3x = 30 - 0.6...
# 241             [J = B + 7, 4J = 6B, J = 14 + 7, B = 14]
# 242    [y = x + 6, x + y = 0, y = x + 6, x + (x + 6) ...
# 243    [2r + 2p = 28, 3r + 3p = 27, r + p = 14, r + p...
# 244    [0.1dx=total value of Luis's coins, 0.25qx=tot...
# 245    [300*0.4=120, 180=300*0.6, 120=300*0.4, 300+x,...
# 246    [20($0.85) + x($1.15) = ($1)(20 + x), 17 + 1.1...
# 247        [48 + 192 = 240, 1200 ÷ 240 = time, time = 5]
# 248    [x + y = 25000, 0.07x + 0.12y = 2450, y = 2500...
# 249    [x + y = 288, x/y = 5/7, 7x = 5y, 5x + 5y = 14...
# 250            [1100 = x + 0.10x, 1100 = 1.1x, x = 1000]
# 251      [24 - x = 3(18 - x), 24 - x = 54 - 3x, 2x = 30]
# 252    [x + y = 36, y = 3x, x + 3x = 36, 4x = 36, x =...
# 253    [x = 0.25(x + 12), x = 0.25x + 3, 0.75x = 3, x...
# 254    [x = son's present age, 4x = father's present ...
# 255    [F = 2(C1 + C2), F + 20 = C1 + C2 + 40, C1 + C...
# 256    [y = 3x, x + y = 28, y = 3(7), x + 3x = 28, 4x...
# 257    [10x + y = 7(x + y), 5y = 9 + x, x = 5y - 9, 1...
# 258    [L = 3S + 7, L - S = 13, (3S + 7) - S = 13, 2S...
# 259    [100 * 2/100 = 2, 2 - 0.02*x + x = 0.05*100, 2...
# 260    [M = 3D - 3, M + D = 45, (3D - 3) + D = 45, 4D...
# 261    [x + (x + 44) = 140, 2x + 44 = 140, 2x = 96, x...
# 262    [x + y = 30, 10x + 20y = 330, x + 2y = 33, x =...
# 263    [$4980 = 87g + 18s, g = s + 15, g - 15 = s, $4...
# 264    [x+y=10, 10y+x=3(10x+y)-2, 10y+x=30x+3y-2, 9y-...
# 265                           [x + y = 15, 3x = 5y - 11]
# 266    [0.2x + 0.7(60) = 0.5(x + 60), 0.2x + 42 = 0.5...
# 267    [0.09x + 0.07(x - 100) = 73, 0.09x + 0.07x - 7...
# 268    [2x + 3y = 21, x - y = 3, x = y + 3, 2(y+3) + ...
# 269    [1/Time = Rate, 1/30 = Rate_Jim, 1/45 = Rate_S...
# 270    [time = distance / speed, t1 = d / 78, t2 = d ...
# 271    [distance/time = distance/time, 54.8/4 = x/5, ...
# 272    [Sam_rate = 1/4, Lisa_rate = 1/6, Tom_rate = 1...
# 273    [0.2(5) = 1, 0.4x = 0.4x gallons of yellow pai...
# 274    [x = (3/4)y, x + y = 63, (3/4)y + y = 63, (7/4...
# 275    [T = B - 3, T + B = 11, B = T + 3, T + (T + 3)...
# 276    [x + y = 6, 0.15x + 0.30y = 1.2, 0.15y = 0.9, ...
# 277    [d + n = 50, 10d + 5n = 430, n = 50 - d, 10d +...
# 278    [x + y = 200, 0.1x + 0.3y = 30, 0.3y - 0.1x = ...
# 279    [1.44x + 1.80(20) = 1.56(x + 20), 1.44x + 36 =...
# 280    [0.095(1 - x) + 0.055x = 0.065(1), 1 - x + 0.0...
# 281    [2x + 14 = larger_number, x + (2x + 14) - 9 = ...
# 282    [rate_first_pipe = 1/8, rate_second_pipe = 1/1...
# 283    [c + a = 225, 6c + 9a = 1875, c = 225 - a, 6(2...
# 284                          [x + y = 24, 4x + 5y = 100]
# 285    [x + (x + 10) = 2x + 10, distance = rate x tim...
# 286    [x = amount invested at 8%, (5400-x) = amount ...
# 287      [42+x=3(8+x), 42+x=24+3x, 42=24+2x, 18=2x, 9=x]
# 288    [d = r x t, d1 = 80t, d2 = 90t, d1 + d2 = 476,...
# 289    [x=5y+2, x+y=24, (5y+2)+y=24, 6y+2=24, 6y=22, ...
# 290                               [a + b = c, b = a - d]
# 291    [5x + 7x = 69, 12x = 69, x = 5.75, 3 * 5.75 = ...
# 292    [x + y = 80, x - y = 12, x = 80 - y, y = x - 1...
# 293    [Amount of acid in 10% solution = 0.1x, Amount...
# 294    [x + y = 18, 3x + 2y = 44, x = 18 - y, 3(18 - ...
# 295    [y = 5x + 7, x + y = 55, x + (5x + 7) = 55, 6x...
# 296    [d = 70(t-2), d = 60t, 60t = 70(t-2), 10t = 14...
# 297    [J = 6B - 4, J + B = 10, (6B - 4) + B = 10, 7B...
# 298    [J = 2P, 16 = (J x 40/60) + (P x 40/60), 16 = ...
# 299                       [2x - 5 = 89, 2x = 94, x = 47]
# 300    [d = 60t, d = 50(8.8-t), 60t = 50(8.8-t), 60t ...
# 301    [time = distance / rate, time = d / 50, time =...
# 302    [time = work ÷ rate, rate 1 = 1/9, rate 2 = 1/...
# 303    [2x = Number of pounds of type B coffee, (4.60...
# 304    [y = 2x + 3, x + y = -15, x + (2x + 3) = -15, ...
# 305    [distance = rate x time, distance jogged = rat...
# 306    [E = A + 6, E + 2 = (A + 2)/3 + 20, E - 2 = (A...
# 307                           [x + y = -11, 2x - y = 32]
# 308    [x + 0.6666x = 600, 1.6666x = 600, x = 360, 0....
# 309    [x + (x + 13,356) = 119,626, 2x + 13,356 = 119...
# 310    [work rate = work / time, combined work rate =...
# 311    [x + y = 12, 5x + 10y = 100, x = 12 - y, 5(12 ...
# 312    [x + y = 9, 10y + x = 10x + y - 27, 9y = 9x - ...
# 313    [x = pounds of $3.50 nuts, 5 - x = pounds of $...
# 314    [x + 20 = Sunday, x + (x + 20) = 110, 2x + 20 ...
# 315    [D = 2C, D + 30 = 0.6666666(C + 30) + 14, 2C +...
# 316    [3600=(p-w) x 5, 3600=(p+w) x 4, 3600/5=p-w, 7...
# 317    [MTA = 3W, MTA12 = 3W + 12, WA12 = W + 12, MTA...
# 318    [y = 5x + 2, y - x = 26, y - x = 26, 5x + 2 - ...
# 319    [x + y = 100,000, 2y = 3x - 25,000, x = 100,00...
# 320    [x + y = 27, x - y = 3, 2x = 30, y = 27 - x, 2...
# 321    [x + 5 = , 3(x + 5) = , 3(x + 5) + 21 = x, 3x ...
# 322                            [y = x + 12, x + 2y = 39]
# 323    [x + y = 1900, 0.09x + 0.02y = 52, 0.07x = 14,...
# 324    [x - 7 = 6(y - 7), x + 1 = 2(y + 1), x = 6y - ...
# 325    [x + 6 = faster_train_speed, combined_speed = ...
# 326    [x + y = 12000, 0.06x + 0.08y = 860, x = 12000...
# 327    [36 + x = 2(11 + x), 36 + x = 22 + 2x, 36 -22 ...
# 328    [x = Cindy's age now, Jim's age now = x + 5, F...
# 329    [x = 100t, t = x/100, 500 - x = 80(5.5 - x/100...
# 330    [0.20(300-x) + 0.80x = 0.25(300), 60 - 0.20x +...
# 331    [e_old = 1/21, e_new = 1/15, (1/21) * x + (1/1...
# 332    [x + y = 48, 3x = y + 32, y = 48 - x, 3x = (48...
# 333    [C = 2E, (C-9) + (E-9) = 6, (2E-9) + (E-9) = 6...
# 334    [x + y = 125, 5x - 3y = 41, 3x + 3y = 375, -2x...
# 335    [x = rate of passenger train, in mph, x - 20 =...
# 336    [M = A - 3, M - 4 = (1/2)(A - 4), (A - 3) - 4 ...
# 337    [distance = rate × time, distance = r × t, dis...
# 338    [x + y = 10, x = 2y + 4, y = 10 - x, x = 2(10 ...
# 339    [x, L = 2x + 3, 2x + 5L = 63, 2x + 5(2x + 3) =...
# 340    [x + y = 10, 1.30x + 2.00y = 17.20, y = 10 - x...
# 341    [x-9, 2x-9, (x-9) + (2x-9) = 3x-18, 3x-18 = 66...
# 342    [58x + 52y = 317, x + y = 5.75, y = 5.75 - x, ...
# 343    [Women's age = 2x + 3, Son's age + Women's age...
# 344    [y = x + 8, 3x = 2y - 6, 3x = 2(x + 8) - 6, x ...
# 345    [x + y = 54, x - y = 4, 2x = 58, x = 29, 29 + ...
# 346    [F = 4S, F + 5 = 3(S + 5), F + 5 = 3S + 15, F ...
# 347    [x + y = 5000, 0.8x + 1.45y = 6500, x = 5000 -...
# 348    [Total cost = (200 oz. x $5.50/oz.) + (500 oz....
# 349    [x + y = 33, x - y = 7, x + y + x - y = 33 + 7...
# 350     [x + 20 = 2(x + 20), 4x + 20 = 2x + 40, 2x = 20]
# 351    [T = 1 + 3C, T + C = 21, 1 + 3C + C = 21, 4C +...
# 352    [time = distance / speed, time = x / 45, time ...
# 353      [x + 3x = 40, 4x = 40, x = 10, 3x = 3(10) = 30]
# 354    [y = 0.2x, x - y = 88, x - 0.2x = 88, 0.8x = 8...
# 355               [0.375x + 25 = x, 0.625x = 25, x = 40]
# 356    [y = x + 8, 5x - 2y = 14, 5x - 2(x+8) = 14, 5x...
# 357    [x + y = 100, 9x + 12y = 11.25(100), y = 100 -...
# 358    [a + b = 8, 10b + a = 10a + b + 18, 9b - 9a = ...
# 359    [x + y = 39, 2x + 3y = 101, x = 39 - y, 2(39 -...
# 360    [x + y = 5, x - y = 13, y = 5 - x, x - (5 - x)...
# 361    [distance = rate × time, distance = rate × tim...
# 362    [10a + 8c = 136, 17a + 2c = 150, a = (136 - 8c...
# 363    [distance = rate x time, distance = 14 x t, di...
# 364    [x + y = 48, x - y = 12, 2x = 60, x = 30, 30 +...
# 365    [M - 3 = 3A + 1, M = 3A + 4, M + 4 = 2(A + 4) ...
# 366    [x = numerator, x + 7 = denominator, (x + 3) /...
# 367    [21 - x = number of quarters, x = number of ni...
# 368                 [y - x = 22, y = 2x + 4, x + 4 = 22]
# 369    [x + y = 150, x/27 + y/23 = 6, x = 150 - y, 23...
# 370    [L = 4N, L - 6 = 7(N - 6), L - 6 = 7N - 42, L ...
# 371    [fill_rate_pipe1 = 1/10, fill_rate_pipe2 = 1/6...
# 372    [3x + 4y = -25, 2x - 3y = 6, -x + 10y = -37, x...
# 373    [L - 5 = 3(Lovely - 5), L + 10 = 2(Lovely + 10...
# 374            [x + y = 39, x - y = 15, 2x = 54, y = 12]
# 375    [x = number of advanced-purchase tickets sold,...
# 376    [x + y = 33, x - y = 9, 2x = 42, x = 21, 21 + ...
# 377    [rate_A = 1/4, rate_B = -1/8, net_rate = rate_...
# 378    [x + y = 200, 1x + 5y = 300, y = 200 - x, x + ...
# 379     [x = 2(x - 6) - 4, x = 2x - 12 - 4, x = 2x - 16]
# 380    [Noe's distance = x * 4, Lily's distance = (x ...
# 381                             [T = 2S - 1, T + S = 14]
# 382    [Larger number = x + 0.20x = 1.20x, x + 1.20x ...
# 383    [0.25x/(x+42) ≤ 0.20, 0.25x ≤ 0.20(x+42), 0.25...
# 384                                                   []
# 385    [Distance = Speed × Time, Distance = 80 × x, D...
# 386    [d + q = 32, 0.10d + 0.25q = 4.70, q = 32 - d,...
# 387    [x + y = 20, 0.1x + 0.18y = 3, 10x + 18y = 300...
# 388    [x + y = 76, y = 5x - 2, x + (5x - 2) = 76, 6x...
# 389    [J - 1 = 3(L - 1), J - 1 = 3L - 3, J = 3L - 2,...
# 390    [x + 2 = larger number, 25(x + 2) + 50x = 500,...
# 391                      [x = 2*(12+x) - (40+x), 16 = x]
# 392    [2x - 3y = 2, x + y = 11, x = 11 - y, 2(11 - y...
# 393                    [A + 3A = 444, 4A = 444, A = 111]
# 394    [x + y = 45, 4x = 5y - 9, x = 45 - y, 4(45 - y...
# 395          [24/60 = x/5, 24*5 = 60x, 120 = 60x, 2 = x]
# 396                  [LCM(64, 56) = 448, distance = 448]
# 397    [10T + U = 8(T + U), 2T = 7U, 6U = 5 + T, T = ...
# 398                  [1250 = 10000*x*1, 1250 = 4000*x*1]
# 399    [0.20 * 80 = 16, 16 = (16 + x) / (80 - x) * 80...
# 400    [0.40(60) + 0.15x = 0.25(60+x), 24 + 0.15x = 1...
# 401    [x = Dianne's age six years ago, 5x = Josie's ...
# 402    [1/2x = x + 3, 2(1/2x) = 2(x + 3), x = 2x + 6,...
# 403    [x + y = 8,000, 0.085x + 0.064y = 575, y = 8,0...
# 404    [J = M + 12, M + J = 40, M + (M + 12) = 40, 2M...
# 405    [T = A - 15 , A - 10 = 4(T - 10), A - 10 = 4((...
# 406       [x + y = 17, 10y + x = 10x + y + 9, y - x = 1]
# 407    [B = 2C - 1, B + C = 26, C = (B + 1)/2, B + (B...
# 408    [1/T = 1/6 + 1/5, 30/T = 5 + 6, 30/T = 11, T =...
# 409               [3x + 2x = 15, 5x = 15, x = 3, 3x = 9]
# 410      [x + (x + 3) = 21, 2x + 3 = 21, 2x = 18, x = 9]
# 411    [x + y = 23, x - y = 5, 2x = 28, x = 14, 14 + ...
# 412    [A + C = 85, 5A + 2C = 275, 2A + 2C = 170, 5A ...
# 413    [distance = rate x time, 50t, 70t, 70t - 50t =...
# 414    [G = 5F, (1/3)(G + F) = 32, F = G/5, (1/3)(G +...
# 415    [x - $1330.50 =  Wednesday'sEarnings, x + (x -...
# 416    [x=(1/3)y, x+y=100, (1/3)y+y=100, y+3y=300, 4y...
# 417    [x + y = 365, 37x + 30y = 407, y = x * 1.2, x ...
# 418    [inlet_rate = 1/10, outlet_rate = 1/15, net_ra...
# 419    [4x + 3y = 15, 3x - 2y = 7, 8x + 6y = 30, 9x -...
# 420    [A = 1/2bh, 4 = 1/2 * 2.5 * h, 8 = 2.5 * h, h ...
# 421    [x + y = 30, 1.5x + 0.9y = 33, y = 30 - x, 1.5...
# 422       [x + (x+2) = 48, 2x + 2 = 48, 2x = 46, x = 23]
# 423    [L - S = 67, L = 6S - 3, (6S - 3) - S = 67, 5S...
# 424    [x = liters of 30% alcohol solution, 0.6*50 = ...
# 425    [3x + 2(x + 33) + 1 = 82, 3x + 2x + 66 + 1 = 8...
# 426    [0.18x + 0.14(22000-x) = 3360, 0.18x + 3080 - ...
# 427    [3x + 7y = 62, x - y = 4, x = y + 4, 3x + 7y =...
# 428    [48 = 3(B + S), 16 = B + S, 48 = 6(B - S), 8 =...
# 429    [effective speed = air speed + wind speed, 800...
# 430    [1/Time taken = Work done, Lisa's rate of work...
# 431                      [x+3=3(2x+3)/5, 5(x+3)=3(2x+3)]
# 432    [0.6x + 0.4(12.4 - x) = 0.5(12.4), 0.2x + 4.96...
# 433    [x + y = 10,000, 0.06x + 0.08y = 760, y = 10,0...
# 434    [1 / (time) = 1/5 + 1/3, 1 / (t) = 3/15 + 5/15...
# 435             [x + (x + 2) = 20, 2x + 2 = 20, 2x = 18]
# 436    [distance_west = 3x, distance_east = 3x + 360,...
# 437    [S + G = 72, G = 7S, S + 7S = 72, 8S = 72, S =...
# 438    [Age difference = Mother's age - Samson's age,...
# 439    [J = James + 10, 2(Joe + 8) = 3(James + 8), Ja...
# 440    [1/t = 1/s + 1/l, 1/t = 4/12 + 3/12, 1/t = 7/1...
# 441    [tank_capacity = 12, fill_time = 2, fill_rate ...
# 442    [s + c = 128, 20s + 35c = 2280, s = 128 - c, 2...
# 443    [Distance covered by the car in x hours = spee...
# 444    [f = 2x + 5, f - 6 = (1/3)(x-6), 2x - 1 = (1/3...
# 445    [x + (x + 11) = 75, 2x + 11 = 75, 2x = 64, x =...
# 446    [J = S + 6, J + 4 = 2(S - 5), J + 4 = 2S - 10,...
# 447    [x + y = 75, 0.20x + 0.33y = 19.95, y = 75 - x...
# 448    [x + y = 200, 0.15x + 0.35y = 54, y = 120, x +...
# 449    [(x + 2x - 7740) / 2 = 99000, (3x - 7740) / 2 ...
# 450    [m = 3x + 6, x + (3x + 6) = 46, 4x + 6 = 46, 4...
# 451    [0.02(70) + 0.05x = 0.03(70 + x), 1.4 + 0.05x ...
# 452    [c + a = 2200, 1.5c + 4a = 5050, c = 2200 - a,...
# 453    [0.12(18000 - x) - 0.05x = 885, 2160 - 0.12x -...
# 454    [C_a = 0.8m, C_b = 50 + 0.5m, 0.8m = 50 + 0.5m...
# 455    [200 = (45 + x) × t, 160 = (45 - x) × t, 200/1...
# 456         [E = 720 - 600, T = 240, D = 0.5, T = E / D]
# 457    [distance = rate × time, distance1 = rate1 × t...
# 458    [y = x + 16, 0.66666y - x = 0.25(x + y), 0.666...
# 459    [d1 = 47(t+2), d2 = 58t, d1 = d2, 47(t+2) = 58...
# 460    [x = 3, 36 - x = 3(14 - x), 36 - x = 42 - 3x, ...
# 461    [A = E - 5, (E + 1) = 3(A - 4), (E + 13) = 3A,...
# 462    [x = y - 3, 2y = 3x - 5, 2y = 3(y - 3) - 5, 2y...
# 463    [t1 = d/15, t2 = d/35, t1 + t2 = 2, d/15 + d/3...
# 464    [d = (s + 3) x 15, d = (s - 3) x 20, d = 15s +...
# 465    [Distance = Rate x Time, Rate downstream = Rat...
# 466    [effective speed = x + 12, distance = (x + 12)...
# 467    [J = R + 5, (J - 10) + (R - 10) = 25, J + R - ...
# 468            [3/10 = b/30, 7/10 = g/30, 3/10 * 30 = 9]
# 469    [J - 5 = M - 5 + 7, J - M = 7, J + 5 = 2(M + 5...
# 470    [(p+w)(60/60) = 100, p+w = 100, (p-w)(100/60) ...
# 471    [M = 5S, M + 3 = 3S + 1, M - 5 = 5(S - 5), M =...
# 472    [x + y = 188, y = 3x + 24, x + (3x + 24) = 188...
# 473    [Interest = Principal x Rate x Time, 980 = x *...
# 474                       [4J + 3JIM = 47, JIM = 2J - 1]
# 475    [Sue's age = D + 4, Sue's age + D = 22, (D + 4...
# 476    [x = 2y + 4, x + y = 25, 2y + 4 + y = 25, 3y +...
# 477    [y = x + 5, 4y + 3x = 97, 4(x + 5) + 3x = 97, ...
# 478     [x = 15, 3x + 15 = 2(x + 15), 3x + 15 = 2x + 30]
# 479    [35 + x = 2(10 + x), 35 + x = 20 + 2x, 35 = 20...
# 480    [x + y = 280, 0.14x + 0.07y = 36.4, x = 280 - ...
# 481    [x = number of years until Daniel is only 4 ti...
# 482    [0.10 × 60 = 6, 60 + x, 6 + x, 0.15 (60 + x), ...
# 483    [time = total work ÷ work rate, work rate toge...
# 484          [3X = X + 34, 3X - X = 34, 2X = 34, X = 17]
# 485    [speed = distance/time, speed = 36 km/3 hours ...
# 486    [T + t = 21, T + 3 = 2(t + 3), T = 2t + 3, 3t ...
# 487    [P = W + 24, P - 4 = 7(W - 4), (W + 24) - 4 = ...
# 488    [0.12x = 0.08(x + 1260), 0.12x = 0.08x + 100.8...
# 489    [$a+b=6$, $(10a+b)-(10b+a)=9(a-b)$, $3(a+b)=18...
# 490    [time north = d/3, time south = d/4, time nort...
# 491            [A = 2B - 10, A + B = 26, B = 12, A = 14]
# 492    [y + x = 55, y = 17x + 1, (17x + 1) + x = 55, ...
# 493    [x + y = 77, y = 32 + 2x, x + (32 + 2x) = 77, ...
# 494          [$55 + $35x = $75 + $30x, $5x = $20, x = 4]
# 495    [y = 5x + 1, x + y = 103, 5x = y - 1, x = (y -...
# 496    [y - x = 6, y = 3x, 3x - x = 6, 2x = 6, x = 3,...
# 497    [M = 2M, M - 9 = 5(M - 9), M = 2X, X - 9, 2X -...
# 498    [4x - 3 = 325, 4x = 325 + 3, 4x = 328, x = 328...
# 499    [1/T = 1/T1 + 1/T2, 1/T = 1/18 + 1/12, 36/T = ...
# 500    [x = y + 6, 6x + 9 = 7y, 6(x+6) + 9 = 7y, 6x +...
# 501    [Donald's age = 12 + x, Father's age = 40 + x,...
# 502    [6x + 5 = 3(x+1) - 7, 6x + 5 = 3x + 3 - 7, 6x ...
# 503    [C = D + 9, C + 7 = D + 16 + 93, C + 7 = D + 1...
# 504    [0.2x + 0.35(60-x) = 0.25(60), 0.2x + 21 - 0.3...
# 505    [S + 12 = Yoshi's age, S + 6 = Yoshi's sister'...
# 506                                                   []
# 507    [x + (5x - 2) = 94, 6x - 2 = 94, 6x = 96, x = ...
# 508    [x + y = 372/4, x + y = 93, x - y = 165/3, x -...
# 509    [x + y = 36, x = y + 2, (y + 2) + y = 36, 2y +...
# 510    [900 = (x+y) × 3, 900 = (x-y) × 4, 900 = 3x + ...
# 511    [x + y = 100, 9x + 12y = 1125, x = 100 - y, 9(...
# 512    [x + (2x + 15) = 54, 3x + 15 = 54, 3x = 39, x ...
# 513    [10x + 5y = 12.5, 7x + 4y = 9, 35x + 20y = 45,...
# 514    [A + S = 846, 6A + 3S = 3846, S = 846 - A, 6A ...
# 515    [9x = Larger number, Larger number - x = 96, 9...
# 516    [0.4x + 0.7y = 0.49(80), x + y = 80, x = 80 - ...
# 517    [d = 45t1, d = 60t2, 45t1 = 60t2, 3t1 = 4t2, t...
# 518    [4x = 2(x+2) - 12, 4x = 2x + 4 - 12, 4x = 2x -...
# 519    [0.5x - 10, (0.5x - 10) - 80, (0.5x - 10) - 80...
# 520    [1. First player's home runs = 7 + 2x, 2. x + ...
# 521    [18 = (x + y) × 2, 18 = (x - y) × 3, 9 = x + y...
# 522    [time = distance / speed, time = d / 5, time =...
# 523    [First fellow's rate = 7 / 3 = 2.33, Second fe...
# 524       [x + y = 750, 7.5x + 4y = 3808.5, y = 750 - x]
# 525    [a + b = 14, 10a + b - 36 = 10b + a, a = 14 - ...
# 526    [1/Time taken by A + 1/Time taken by B = 1/Tim...
# 527    [x + y = 85, 15x + 67y = 3875, y = 85 - x, 15x...
# 528    [900 = (a - w) * 6, 150 = a - w, 900 = (a + w)...
# 529                         [x + y = 6, 0.4x + 0.8y = 3]
# 530                      [3x + y = 1.75, 2x + 4y = 2.00]
# 531    [y = 2x + 8, x + y = 20, x + (2x + 8) = 20, 3x...
# 532    [y = x + 14, x + y = 70, x + (x + 14) = 70, 2x...
# 533    [time = volume ÷ rate, rate of A = volume ÷ ti...
# 534    [x + y = 42, 6x - 3y = 90, x = 42 - y, 6(42 - ...
# 535    [H + 2 = 2(L + 2), H = 8, 10 = 2L + 4, 5 = L +...
# 536    [x + y = 22, x - y = 4, x + y + x - y = 22 + 4...
# 537    [x + y = 90, 3x = y + 10, x = 90 - y, 3(90 - y...
# 538     [x + (3x - 4) = 16, 4x - 4 = 16, 4x = 20, x = 5]
# 539    [0.04x + 0.01(90 - x) = 0.03(90), 0.04x + 0.9 ...
# 540    [x = 5y - 12, x + y = 162, 5y - 12 + y = 162, ...
# 541    [y = x + 3, 4x - 3y = 4, 4x - 3(x + 3) = 4, x ...
# 542    [x = amount_{20\%}, 50 - x = amount_{40\%}, am...
# 543    [distance = speed x time, Distance traveled by...
# 544    [x + y = 2x - 6, x - y = 4y - 10, x = y + 6, (...
# 545    [3x : 2x, 3 : 2, 6x : 5x + 6, 6 : 5 + (6/5), 6...
# 546    [y = 2x + 8, x + y = 3y - 10, x + (2x + 8) = 3...
# 547    [x = 5, Dorothy's age = 3x, 3x + 5 = 2(x+5), x...
# 548    [x + (3x + 9) = 53, 4x + 9 = 53, 4x = 44, x = 11]
# 549    [E + M = 20, (E + 1) = 10(M - 1), E = 20 - M, ...
# 550    [x = speed of the plane flying east, 2x = spee...
# 551    [x + y = 55, x/25 + y/40 = 1825/55, 4x + 2.5y ...
# 552    [R = 2P, R + 4 = 3(P - 3), 2P + 4 = 3(P - 3), ...
# 553    [x = current age, (x - 5) * 2 = brother's age ...
# 554                   [f = 35 + a + x, f = 2y, y = 0.5f]
# 555            [x + 2x = 114, 3x = 114, x = 38, 2x = 76]
# 556    [time1 = d/48, time2 = d/60, time1 - time2 = 2...
# 557    [y - x = 3.2, x + y = 46.4, y = x + 3.2, x + (...
# 558    [J = 2M + 5, J + M = 29, J - 5 = 2M, J + M - 5...
# 559    [A + C = 130, 12A + 4C = 840, A = 130 - C, 12(...
# 560    [x + (x + 37) = 55, 2x + 37 = 55, 2x = 18, x =...
# 561               [x + 2x = 18, 3x = 18, x = 6, 2x = 12]
# 562    [ba = ab + 9, a + b = 13, a = 13 - b, ba = (13...
# 563    [3/33 = x/100, x = 9.09%, y / (33 + y) = 25/10...
# 564    [Q + D = 23, 0.25Q + 0.10D = 3.35, 25Q + 10D =...
# 565    [x + y = 275, 2x + y = 402, -2x - 2y = -550, -...
# 566    [Average speed = (speed going out + speed comi...
# 567    [x + y = 52, x + 5y = 184, x = 52 - y, (52 - y...
# 568    [distance_east = speed_east × time_east, dista...
# 569    [rate_pump = 1/6, rate_hose = 1/10, rate_combi...
# 570    [x = 6y + 10, 5x - 5y = 550, 5(6y + 10) - 5y =...
# 571    [distance = rate x time, distance = x * 8, dis...
# 572       [x + y = 29, 0.25x + 0.10y = 5.45, y = 29 - x]
# 573      [x + 11x = 15, 12x = 15, x = 1.25, 11x = 13.75]
# 574    [x + y = 143, y = 3x + 3, x + (3x + 3) = 143, ...
# 575    [time = total work / rate, rate of pipe 1 = 1 ...
# 576    [2(x + x - 55) = 510, 2(2x - 55) = 510, 4x - 1...
# 577    [d = 20t, 70 - d, 4.5 - t, 70 - d = 12(4.5 - t...
# 578    [x = Marilou's current age, Perla's current ag...
# 579    [x + y = 54, x - y = 22, x = y + 22, y + 22 + ...
# 580    [Time = Work ÷ Rate, Rate Anna = 1/4 house per...
# 581    [y = x + 4, 10y + x - 1 = 2(10x + y), 9y - 19x...
# 582    [Tom's age = 3A, A + 3A = 54, 4A = 54, A = 13....
# 583    [x + y = 104, y = 2x - 1, x + (2x - 1) = 104, ...
# 584    [1/T = 1/T1 + 1/T2, 1/T = 1/12 + 1/10, 1/T = (...
# 585    [x + y = 61, y - x = 5, y = 61 - x, (61 - x) -...
# 586    [x + y = 75, 0.06x + 0.03y = 3.75, 6x + 3y = 3...
# 587    [distance = rate x time, distance = 60t - 44t,...
# 588    [a + b = 11, 10b + a = 2(10a + b) + 7, 10b + a...
# 589    [x + y = 56, y = 2x + 8, 2x + 8 = y, 2x = y - ...
# 590    [5x + 6 = 7/5 * (3x + 6), 25x + 30 = 21x + 42,...
# 591                      [4x - 23 = 21, 4x = 44, x = 11]
# 592    [y = x + 12, x + 2y = 39, x + 2(x + 12) = 39, ...
# 593    [x + 3x = 48, 4x = 48, x = 12, 3(12) = 36, 12 ...
# 594    [x + 20 = plane_speed_with_wind, x - 20 = plan...
# 595    [x + y = 12, 3x + 6 = 4y - 7, x = 12 - y, 3(12...
# 596    [x + y = 60, x = 2y + 16, 2y + 16 + y = 60, 3y...
# 597    [y = x + 3, y/x = 1.5, (x + 3)/x = 1.5, x + 3 ...
# 598    [L = 3S - 1, L + S = 63, (3S - 1) + S = 63, 4S...
# 599             [3x - y = 8, x + y = 12, 2x =-4, y = 14]
# 600    [x+27 = mother's current age, x-1 = daughter's...
# 601    [x = y + 6, x + y = 32, y + y + 6 = 32, 2y + 6...
# 602    [Steel/Copper = 108/7, x + y = 230, x/y = 108/...
# 603    [0.333C + 3 = 0.5C, 0.5C - 0.333C = 3, 0.167C ...
# 604    [12 = (c-x) x 6, 2 = c-x, 12 = (c+x) x 0.75, 1...
# 605    [x + (x + 1) = -105, 2x + 1 = -105, 2x = -106,...
# 606    [x + y = 4500, 0.093x + 0.113y = 486, x = 4500...
# 607    [440 = x * 2, 440 = (x+126) * 2, x+126 = 220, ...
# 608    [0.6 x 50 = 30, 0.6 x (50 - x) + 0.4 x = 0.46 ...
# 609    [x + y = 9, 2x + 3y = 22, x = 9 - y, 2(9 - y) ...
# 610    [3x + 2y = 29, 4x - 3y = 16, 2y = 29 - 3x, y =...
# 611    [distance = rate × time, distance = (x + x + 1...
# 612                                                   []
# 613    [y - x = 67, y = 6x - 3, (6x - 3) - x = 67, 5x...
# 614        [distance = rate x time, 910 = 140t, t = 6.5]
# 615    [y - x = 264, y = 3x, 3x - x = 264, 2x = 264, ...
# 616                  [9 + x = 40 - 4x, 5x = 31, x = 6.2]
# 617    [distance = rate x time, T = 310, 124t = 310, ...
# 618    [1/T = 1/A + 1/B, A = 3, B = 7, 1/T = 1/3 + 1/...
# 619                     [b + c = 12, b - c = 8, 2b = 20]
# 620    [d = 16t, d = 72 - 24t, 16t = 72 - 24t, 40t = ...
# 621    [t = d / s, t1 = 60 / 21, t2 = 60 / 15, t_meet...
# 622    [A = S + 5, A + S = 27, 2S + 5 = 27, 2S = 22, ...
# 623    [x + y = 1520, 3x = 2y, y = (3/2)x, (5/2)x = 1...
# 624        [x + y = 30, 5x = 2y + 17, y = (5/2)x - 17/2]
# 625    [a+b=8, b=8-a, 10a+b+16=10a+(8-a)+16=18+a, 3(1...
# 626    [x = 12/7(some number - 275), 7/12 x + 275 = s...
# 627    [0.75(100) = 0.30x + 0.90(100 - x), 75 = 0.30x...
# 628    [d_t = 45*(t+1), d_c = 60*t, d_t = d_c, 45*(t+...
# 629     + 8b = 24.60, 3m + 5b = 14.25, 6m = 24.60 ...
# 630    [distance = speed × time, B × 0.5 + C × 0.5 = ...
# 631    [3 + 2 = 5, 250 ÷ 5 = 50, 3 x 50 = 150, 2 x 50...
# 632    [12x = budgeted price for 12 gallons, x + 0.30...
# 633                      [23x + 35y = 490, y = x - 0.50]
# 634    [32+x, 154+x, 154+x = 3(32+x), 154+x= 96+3x, 2...
# 635    [x + (15 + 2x) = 120, 3x + 15 = 120, 3x = 105,...
# 636      [x + y = 75, 0.05x + 0.08y = 4.8, 0.03y = 1.05]
# 637    [33 + x = 4(6 + x), 33 + x = 24 + 4x, 33 = 24 ...
# 638    [d + q = 15, 10d + 25q = 300, d = 15 - q, 10(1...
# 639    [x + y = 4725, 0.11x = 0.16y, y = 4725 - x, 0....
# 640    [distance = 58t, distance = 62t, total time = ...
# 641    [(1/6)(x-8) = (1/10)(x+8), 10(x-8) = 6(x+8), 1...
# 642    [time = work / rate, rate_A = 1/3, rate_B = 1/...
# 643    [x + y = 39, x - y = 11, (x + y) + (x - y) = 3...
# 644    [N + 4 = 3(D + 4), N + 4 = 3D + 12, N = 3D + 8...
# 645    [x + y = 45, 10x + 57y = 1625, x = 45 - y, 10(...
# 646    [d_e = 6x, d_w = 6(x+5), 510 = 6x + 6(x+5), 51...
# 647    [x + y = 135, 2x + 3y = 280, x = 135 - y, 270 ...
# 648    [distance = rate x time, 110 = 44t, t=110/44, ...
# 649    [14y = 13x, 14 * 13 = 182, 182y = 182x, y = x,...
# 650    [M = 7S, M + 8 = 3(S + 8), 7S + 8 = 3(S + 8), ...
# 651    [x = 6, 3x = 18, 0.10x + 0.15x = 1.50, 0.25x =...
# 652    [y = x + 5, 8x - 5y = 11, 8x - 5(x + 5) = 11, ...
# 653              [x + 4x = 70, 5x = 70, x = 14, 4x = 56]
# 654    [y = x + 48, x + y = 120, x + (x + 48) = 120, ...
# 655    [0.15x = profit_1, 0.05x = loss_2, total_incom...
# 656       [x + 2x+9 = 45, 3x+9 = 45, 3x = 36, 2x+9 = 33]
# 657    [x + y = 44, y = 3x - 2, x + (3x - 2) = 44, 4x...
# 658    [d = distance, d/15 = time_to_school, d/10 = t...
# 659    [3x = 4y, x + y = 21, x = 21 - y, 3x = 4y, 3(2...
# 660            [N + D = 50, 5N + 10D = 350, N + 2D = 70]
# 661    [2x = 2[(2/3)x + 8], 2x = (4/3)x + 16, 2x - (4...
# 662    [y = x + 7, x + y = 101, x + (x + 7) = 101, 2x...
# 663    [y - x = 10, y = 2x + 4, (2x + 4) - x = 10, x ...
# 664                           [3M + 2T = 77, M + T = 28]
# 665    [10x+y = 3(x+y), 7x = 2y, 10x+y = 10y+x-45, 9x...
# 666                        [C = A + 8, 7.5C + 12A = 138]
# 667    [y = 3x + 2, 4x = y + 5, 4x = (3x + 2) + 5, x ...
# 668    [20x = total cost of buying x apples, 30(x-2) ...
# 669    [x + 2 = 2(x - 3), x + 2 = 2x - 6, 2 = x - 6, ...
# 670    [x + y = 53, 3x = y - 1, y - 1 = 3x, y = 3x + ...
# 671    [x = 2y + 5, x + y = 89, (2y + 5) + y = 89, 3y...
# 672    [y = x + 2, 9x - 2y = 52, y = x + 2, 9x - 2(x ...
# 673    [d = 5t, d = 3(4 - t), 5t = 3(4 - t), 8t = 12,...
# 674    [x = y + 10, distance = rate × time, 3x + 3y =...
# 675    [y = x + 3, x - 4y = 6y - 12, x = 10y - 12, (x...
# 676    [x + y = 10,000, 0.06x - 0.05y = 160, y = 10,0...
# 677    [M = 3J, M - 3 = 2(J + 3), M - 3 = 2J + 6, M =...
# 678    [G - 5 = 2(T), G + 7 = 5(T + 7), G - 5 = 2T, G...
# 679    [x + 5x = 72, 6x = 72, x = 12, 5x = 60, 12 + 6...
# 680    [3x + 20 = x + 12, 3x - x = 12 - 20, 2x = -8, ...
# 681    [S = 7L, S + 6 = 5(L + 6), 7L + 6 = 5(L + 6), ...
# 682    [C + H = 30, 4C + 2H = 100, C = 30 - H, 4(30 -...
# 683    [t=3u+2, 10u+t=\frac{1}{2}(10t+u)-13, 19u=4t-3...
# 684                             [x + y = 50, x = 2y - 1]
# 685    [Bigger number = 3x + 5, x + bigger number = 1...
# 686    [x = y - 2, 2x = 3y + 4, x = y - 2, 2(y - 2) =...
# 687    [x + y = $10,000, 0.06x + 0.09y = $684, x = ($...
# 688    [a + c = 578, 2a + 1.5c = 985, a = 578 - c, 2(...
# 689    [Ben: 1h -> 1/3 fence, Billy: 1h -> 1/4 fence,...
# 690    [d = (16-x) * (1/3), 3d = 16-x, d = (16+x) * (...
# 691                    [x + y = 50, 6.75x + 5.00y = 285]
# 692    [3x + y = 86, 2x = y - 1, y = 2x + 1, 3x + (2x...
# 693    [y = x + 4, 2y = 5x - 7, 2(x + 4) = 5x - 7, 2x...
# 694    [y - x = 16, 5x = 2y - 8, y = x + 16, 5x = 2(x...
# 695    [x + y = 28, y = 3x, x + 3x = 28, 4x = 28, x =...
# 696    [X = John's current age, X - 5 = (X + 8) / 2, ...
# 697    [m + j = 70, m - j = 32, 2m = 102, m = 51, 51 ...
# 698    [10d + 5(d + 3) = 45, 15d + 15 = 45, 15d = 30,...
# 699    [x + y = 39, 0.6x + 0.54y = 22.62, y = 39 - x,...
# 700    [1/Time taken to do a task = Rate of work, Sar...
# 701    [y = 2x - 5, x + y = 52, x + (2x - 5) = 52, 3x...
# 702    [3x + y = 1.75, 2x + 4y = 2.00, y = 1.75 - 3x,...
# 703              [x + y = $10,000, 0.11x - 0.04y = $650]
# 704    [Sylvia's work rate: 1/45 job/minute, Carla's ...
# 705     [0.2 + x = 0.25 * (2 + x), 0.75x = 0.3, x = 0.4]
# 706                     [B = U/3, U = 3B, U = 24, B = 8]
# 707    [x = 60, 79 + (x + 47) + x = 246, 126 + 2x = 2...
# 708    [x + 3 = d, 3x = r, 1 * (x + 3) = d, 3x + x + ...
# 709        [4J + 5 = 3(J + 5), 4J + 5 = 3J + 15, J = 10]
# 710    [ x + y = 63,  x - y = 5,  2x = 68,  x = 34,  ...
# 711    [n + d = 25, 0.05n + 0.1d = 1.95, 5n + 10d = 1...
# 712    [M = 2M + 1, M + M + 1 = 37, 2M + 1 = 36, 2M =...
# 713    [d/60 + d/40 = 1, (2d + 3d)/120 = 1, 5d/120 = ...
# 714    [A + C = 400, 25A + 15C = 7200, A = 400 - C, 2...
# 715    [0.3x + 1.0(14 - x) = 0.4(14), 0.3x + 14 - x =...
# 716        [y = x + 5, 2x + 3y = 80, y = 13 + 5, x = 13]
# 717    [effective speed = r + s, 372 = (r + s) x 4, 9...
# 718    [d = 4x, d = 6(3-x), 4x = 6(3-x), 4x = 18 - 6x...
# 719    [x + x/5 = 216, 5x + x = 1080, 6x = 1080, x = ...
# 720    [Let x be the amount invested at 6.5%, 0.065x ...
# 721    [0.05x + 0.09(10000-x) = 660, -0.04x = -240, x...
# 722                           [5x + 2y = 2, 2x + y = 26]
# 723           [0.05x + 0.10(8-x) = 0.70, -0.05x = -0.10]
# 724    [x + (x + 20) = 40, 2x + 20 = 40, 2x = 20, x =...
# 725    [y - x = 3, x + y = 13, y = x + 3, x + (x + 3)...
# 726    [time = distance / speed, d / 45 = t1, d / 30 ...
# 727    [M = 4J, M - J = 42, 4J - J = 42, 3J = 42, J =...
# 728                     [x = 11/6, 11 + x = 7x, 6x = 11]
# 729    [x + 7 = 2y, y + 20 = 4x, y = (x + 7)/2, (x + ...
# 730    [x = number of pounds of the cheaper kind of f...
# 731    [x = 2y + 7, x + y - 9 = 13, 2y + 7 + y - 9 = ...
# 732    [x - y = 16, 3/4x = 1/2y + 14, x = 2/3y + 56/3...
# 733    [0.09x + 0.11(3x) = 1680, 0.09x + 0.33x = 1680...
# 734    [0.25q + 0.05(2q) = 4.90, 0.25q + 0.10q = 4.90...
# 735    [x = years ago when Danny was thrice as old as...
# 736    [150 - w = actual speed of plane with headwind...
# 737                   [35 + x = 3(9 + x), 2x = 8, x = 4]
# 738    [M = 4J - 3, M + J = 52, 4J - 3 + J = 52, 5J -...
# 739    [x + y = 36, 6.99x + 10.99y = 331.64, x = 36 -...
# 740    [40x + 82(x+0.015) = 1282, 40x + 82x + 1.23 = ...
# 741    [P + M = 47, M = 2P + 14, P + (2P + 14) = 47, ...
# 742    [x + y = 48, x - y = 80, x =  48 - y, (48 - y)...
# 743    [s - 6 = 3(u - 6), s + 4 = 2(u + 4), s = 3u - ...
# 744    [x = rate of slower train, x + 5 = rate of fas...
# 745    [t = 12 / (20 + x), t = 6 / (20 - x), 12 / (20...
# 746    [x + y = 2200, 10x + 15y = 26600, x = 2200 - y...
# 747    [1/4x + 1/5x = 9/20x, 1/8x + 13 = 9/20x, 9/20x...
# 748    [x = number of nickels, (2x-36) = number of pe...
# 749    [D = x * 6, D = (x + 12) * 5, D/6 = x, D = (D/...
# 750    [x + y = 40, 2x + 4y = 100, x = 40 - y, 2(40-y...
# 751    [y=x+6, x+3y=34, x+3(x+6)=34, x+3x+18=34, 4x+1...
# 752    [distance = rate x time, distance = x * 8 mile...
# 753    [y = x + 7, 2x + y = -20, 2x + (x + 7) = -20, ...
# 754    [n + d = 70, 0.05n + 0.10d = 5.55, 5n + 10d = ...
# 755    [first_pipe_filling_rate = 1/5, second_pipe_fi...
# 756    [5x + 50 = 200 - x, 5x + x = 200 - 50, 6x = 15...
# 757    [12x = (x + 20) * 2, 12x = 2x + 40, 10x = 40, ...
# 758    [f + d = 44, f = 3d + 4, 3d + 4 + d = 44, 4d +...
# 759    [n + d = 34, 5n + 10d = 250, n + 2d = 50, d = ...
# 760    [R + U = 1096, 25R + 20U = 26170, R = 1096 - U...
# 761    [x + y = -17, x = 3y - 1, (3y - 1) + y = -17, ...
# 762    [x + y = 100, y = 2x - 5, x + (2x - 5) = 100, ...
# 763                   [2x + 5 - x = 9, x + 5 = 9, x = 4]
# 764    [j = jnc + 7, j + jnc = 41, (jnc + 7) + jnc = ...
# 765    [D + DL = 41, D + 5 = 2(DL + 5), D = 41 - DL, ...
# 766    [x + y = 4500, 8x + 4.25y = 30000, y = 4500 - ...
# 767    [x - 0.25x = 0.75x, x = 0.75x + 40, 0.25x = 40...
# 768    [x = distance Esther drove to work, 2x = total...
# 769    [y = 4x - 3, x + y = 117, x + (4x - 3) = 117, ...
# 770    [Distance = x × 3, Distance = (x+5) × 3, Dista...
# 771    [7x + 2y = 111, x = y + 3, 7(y+3) + 2y = 111, ...
# 772    [$60 = 100 * 0.60, $1.10x = x * 1.10, $70 + $0...
# 773    [SlowPainterStart = 2, SlowPainterTime = 6, Fa...
# 774    [x = number of adult tickets sold, child ticke...
# 775    [G = 2S + 10, G - 1 = 3(S - 1) - 4, G - 1 = 3S...
# 776    [x + y + z = 24, 10x + 14y + 20z = 384, 0.90x ...
# 777    [x + y = 63, x - y = 5, 2x = 68, x = 34, x + y...
# 778    [16 = (b + c) x (20/60), 16 = (b + c) x (1/3),...
# 779    [3a + 7o = 4.56, o = a + 0.28, 3a + 7(a + 0.28...
# 780    [x + y = 50, x - y = 10, x + y + x - y = 50 + ...
# 781    [1/10*X=1/1, 1/12*X=1/1, X/10-X/12=1, 12X/120-...
# 782    [x + 9, 3(x + 9) = 5x + 7, 3x + 27 = 5x + 7, 2...
# 783    [x + y = 73, 5x = y + 149, y = 73 - x, 5x = (7...
# 784    [W = 4x + 1, W + 4 = 3(x + 4), 4x + 1 + 4 = 3(...
# 785    [x-110=speed of the eastbound plane, distance ...
# 786    [Time = Work ÷ Rate, Rate of Sara = Work ÷ Tim...
# 787    [distance = rate x time, distance = 45t, dista...
# 788                           [x + y = 15, 3x = 5y - 11]
# 789    [x + y = 89, x - y = 19, 2x = 108, y = 89 - x,...
# 790    [4 = 2(x-y), 16 = x+y, 2 = x-y, y = 16 - x, 2 ...
# 791    [15 - x, 48 - x, 48 - x = 4(15 - x), 48 - x = ...
# 792    [y = 2x + 10, x/y = 5/12, x = (5/12)y, y = 2(5...
# 793    [y = 2x - 4, x + y = 23, x + (2x - 4) = 23, 3x...
# 794    [Y = (1/3)x + 10, x + Y = 46, x + (1/3)x + 10 ...
# 795    [x + y = 10000, 0.08x + 0.09y = 840, y = 10000...
# 796    [B + C = 66, C = 3B + 2, B + (3B + 2) = 66, 4B...
# 797    [x + 3 = 3(y + 3), x - 1 = 7(y - 1), x = 3y + ...
# 798                   [X + Y = 2000, 0.03X + 0.02Y = 54]
# 799    [a = 4d, a - 7 = 11(d - 7), a - 7 = 11d - 77, ...
# 800    [x = son's age, 2x = father's age, x-12 = son'...
# 801    [1/x = 1/a + 1/b + 1/c, 1/x = 1/30 + 1/45 + 1/...
# 802    [y = x + 8, x + y = 80, x + (x + 8) = 80, 2x +...
# 803    [210x + 130y = total_cost, x + y = 5, (210x + ...
# 804    [x + y = 18, 18 * 2.30 = 41.40, Total cost = 2...
# 805    [Time = Work ÷ Rate, Rate = 1/2 + 1/3 = 5/6 wi...
# 806    [x + y = 250, 15x + 22.5y = 4995, x = 250 - y,...
# 807                          [x + 2x = 9, 3x = 9, x = 3]
# 808    [x + y = 320, 0.08x + 0.13y = 35.2, 0.05y = 9....
# 809                         [n + d = 35, 5n + 10d = 285]
# 810           [y = 7x, x + y = 100, y = 7(12.5) = 87.50]
# 811                              [x + 2 = 2x - 6, x = 8]
# 812    [y = x - 3, 2x + 4y = 36, 2x + 4(x - 3) = 36, ...
# 813    [x + y = 10, 10.50x + 8.50y = 93.00, x = 10 - ...
# 814    [3x + 7x = 10x, (2/5) * 10x = 4x, 4x = 32, x =...
# 815    [x = Aaron's age now, Julie's age now = 4x, Aa...
# 816    [x + y = 150, 5x + 8y = 930, x = 150 - y, 5(15...
# 817    [0.20x + 0.12(200 - x) = 0.15(200), 0.20x + 24...
# 818    [L + S = 2(L - S), L + S = 2L - 2S, L + 3S = 2...
# 819    [1/T = 1/A + 1/B, 1/T = 1/2 + 1/3, 1/T = 5/6, ...
# 820    [x + y = 100, x - y = 14, x + y + x - y = 100 ...
# 821           [x + y = 20,000, 0.08x + 0.12y = 1,836.88]
# 822    [D = 6T + 5, D + T = 94, 6T + 5 + T = 94, 7T +...
# 823    [x = 2(x-5), x = 2x - 10, x - 2x = -10, -x = -...
# 824    [x + y = 480, 10x + 12y = 5280, 5x + 6y = 2640...
# 825    [x - y = (x+y) - 4, x = y + 1, (y+1) - y = ((y...
# 826    [x + y = 1, y = 5x - 11, x + (5x - 11) = 1, 6x...
# 827    [Jose = 1/7, Alex = 1/5, Together = 1/7 + 1/5 ...
# 828    [x + $1200 = senior, x + (x + $1200) = $5000, ...
# 829    [x + y = 5, 0.01x + 0.09y = 0.162, y = 5 - x, ...
# 830    [L + 5 = R, L - 5 + L = 25, 2L - 5 = 25, 2L = ...
# 831    [0.30x + 0.80y = 18, x + y = 40,  y = 40 - x, ...
# 832    [x = time for pumps to fill the trough togethe...
# 833           [5x - x = 200, 4x = 200, x = 50, 5x = 250]
# 834                    [x + y = -3, x - y = 27, 2x = 24]
# 835     [x + (x + 6) = 44, 2x + 6 = 44, 2x = 38, x = 19]
# 836    [x/y = 6/5, 5x = 6y, y = (5/6)x, x - y = 8, x ...
# 837    [x + y = 14, 10x + y = 11x - 2, y = 10x - 2, x...
# 838    [x + y = 9000, 0.09x + 0.08y = 770, x = 9000 -...
# 839    [Distance = Speed x Time, x * 0.8 = (x+6) * 0....
# 840    [x + y = 15, 0.1x + 0.01y = 0.3, 10x + y = 30,...
# 841     [20x = 2.65x + 10,410, 17.35x = 10,410, x = 600]
# 842    [250x + 75(x + 9) = 2300, 250x + 75x + 675 = 2...
# 843    [Amount invested at 6.5% = 2x - $400, 0.05x, 0...
# 844            [x + y = 56, 10x + 5y = 440, 2x + y = 88]
# 845    [x * 60 = y * 60 + 30, x - y = 0.5, (x + y) * ...
# 846    [1 / t = r, 1 / 50 = a, 1 / 20 = b, r = a + b,...
# 847    [x = amount of $30 per ton rock, 24 - x = amou...
# 848    [4x = total number of legs from cows, 2y = tot...
# 849    [x + (x-30) = 2x-30, 390 = 3(2x-30), 390 = 6x ...
# 850    [y = 4x, y = 3(y-x) - 20, 4x = 3(4x-x) - 20, 4...
# 851    [x + y = 160, t = 10 + 5 = 15, C = xt + yt, C ...
# 852    [6 = d/x, 8 = d/(x-10), 6x = d, 8(x-10) = 6x, ...
# 853    [y = 5x - 8, x + y = 28, x + (5x - 8) = 28, 6x...
# 854    [x + y = 20, 3x = 2y, y = (3/2)x, x + (3/2)x =...
# 855    [D + P = 15, 4D + 2P = 42, P = 15 - D, 4D + 2(...
# 856    [x + (x+1) = 27, 2x + 1 = 27, 2x = 26, x = 13,...
# 857    [0.9x = cost of lima beans, 0.5(16) = cost of ...
# 858    [x + y = 50, 0.05x + 0.10y = 4.20, x = 50 - y,...
# 859    [y + 22 = 4(x + 22) - 297, y + 22 = 4x + 88 - ...
# 860    [2b + 3c = 9.75, 4b + 2c = 12.50, 4b + 6c = 19...
# 861    [B - C = 300/5, B - C = 60, B + C = 300/2, B +...
# 862    [x + y = 36, y = 2x + 3, y = 36 - x, 36 - x = ...
# 863    [x + 3x = 4x, 4x = 80, x = 20, 3x = 60, 20 + 6...
# 864    [2x = 3y, x + y = 20, x = (3/2)y, (3/2)y + y =...
# 865    [3.45x + 51 = 3(x + 20), 3.45x + 51 = 3x + 60,...
# 866    [5 + 0.1x = 0.4(5 + x + y), 0.3x -0.4y = -3, 5...
# 867      [a + b = 13, 10b + a = 10a + b - 9, b - a = -1]
# 868    [5(x - 1) = 2x + 3, 5x - 5 = 2x + 3, 3x - 5 = ...
# 869    [x + y = 28, x - y = 2, x = y + 2, (y + 2) + y...
# 870    [y - x = 10, y = 2x - 6, (2x - 6) - x = 10, x ...
# 871    [M = 4K, M - 4 = 6(K - 4), M = 6K - 20, 6K - 2...
# 872    [distance = rate × time, Distance traveled by ...
# 873    [time = distance / speed, x / 7 + (90 - x) / 2...
# 874    [Randy_work_rate = 1/30, Candy_work_rate = 1/4...
# 875    [x = amount invested at 8%, 5000 - x = amount ...
# 876    [distance = rate × time, distance of Train A =...
# 877    [q + d = 45, 0.25q + 0.10d = 8.85, q = 45 - d,...
# 878    [0.25x + 0.5y = 450, x + y = 1000, x = 1000 - ...
# 879    [x/2 = remaining tickets after selling one hal...
# 880    [96=(b-c)×8, 192=(b+c)×5, b-c=12, b=12+c, 192=...
# 881    [x + (x + 5) = 21, 2x + 5 = 21, x = 8, Jenna's...
# 882    [y = x - 5, 6y - 3x = 3, 6(x-5) - 3x = 3, 6x -...
# 883    [4p + 25s = 1580, 4(p/2) + 25(5s/4) = 1315, 2p...
# 884    [Age in 5 years = x + 5, Age in 6 years = x + ...
# 885    [A = T + 6, A + T = 26, (T + 6) + T = 26, 2T +...
# 886    [M = 2F, M + F = 45, 2F + F = 45, 3F = 45, F =...
# 887    [9(10x+y) = 2(10y+x), 90x+9y = 20y+2x, 88x = 1...
# 888                [x + y = -9, max(x,y) - min(x,y) = 1]
# 889    [x = years from now that Jen will be 3 times a...
# 890         [240t + 360t = 500, 600t = 500, t = 500/600]
# 891       [x + (x+2) ≥ 36, 2x + 2 ≥ 36, 2x ≥ 34, x ≥ 17]
# 892    [S = J + 10, 6J - 2S = J + 7, 6J - 2(J + 10) =...
# 893    [x = current age of Todd, 4x = current age of ...
# 894    [x=(1/3)y, x+y=2y-1, (1/3)y+y=2y-1, (4/3)y=2y-...
# 895      [4x, 7x, 4x - 7x = -3x, -3x = 9, -3x/-3 = 9/-3]
# 896    [x + y = 94, y = 2x - 5, x + (2x - 5) = 94, 3x...
# 897    [0.4x = amount of sulfuric acid in x liters of...
# 898    [B = E + 4, B + E = 28, (E + 4) + E = 28, 2E +...
# 899    [x = time taken to paint the house together, A...
# 900    [x = 60, $6x + $14x = $1200, $20x = $1200, $6 ...
# 901    [x + y = 248, x - y = 64, 2x = 312, x = 156, 1...
# 902    [S = (1/4)D, D - S = 27, D - (1/4)D = 27, (3/4...
# 903    [J = 3R, J + R = 72, 3R + R = 72, 4R = 72, R =...
# 904    [x = 4y + 5, x + y = 35, 5y + 5 = 35, 5y = 30,...
# 905    [M = 2S + 1, M - S = 18, S + 1 = 18, S = 17, M...
# 906    [distance = rate x time, distance between cars...
# 907    [y = 2x, 8x = 2y + 2, y = 2x, 8x = 2(2x) + 2, ...
# 908    [y = x + 9, x + y = 27, x + (x + 9) = 27, 2x +...
# 909    [O = 4x + 7, x + O = 27, 5x + 7 = 27, 5x = 20,...
# 910    [y - x = 34, y = 3x, 3x - x = 34, 2x = 34, x =...
# 911    [x + y = 178, x = 2y - 26, 2y - 26 + y = 178, ...
# 912                    [d/3 + d/9 = 8, 4d/9 = 8, d = 18]
# 913    [Number of wins = 14 + 3x, x + (14 + 3x) = 130...
# 914    [x + y = 100, 3x + 5y = 425, 3x + 3y = 300, 2y...
# 915    [2L = 5S + 3, 4L + 3S = 71, L = (5/2)S + (3/2)...
# 916    [weighted average = (a * x + b * y) / (x + y),...
# 917           [ab = 7b, 10a + b = 7b, 10a = 6b, 5a = 3b]
# 918    [x + (2x - 45) = 180, 3x - 45 = 180, 3x = 225,...
# 919                          [x + y = 24, 7x + 5y = 146]
# 920                  [62 = x * 96, x = 62/96, x ≈ 0.646]
# 921      [x + (x - 3) = 15, 2x - 3 = 15, 2x = 18, x = 9]
# 922    [($40 + $0.04(x-600)), 40x + 0.04(x-600)(x>600...
# 923    [40x + (40 + 0.04y)y = 40x + 40y + 0.04y^2, 40...
# 924    [x + y = 10, 3x = 4y + 2, y = 10 - x, 3x = 4(1...
# 925    [d = 20t1, d = 30t2, t1 + t2 = 1.5, t1 = d/20,...
# 926    [9 / 15 = x / 202, 9 * 202 = 15 * x, 1818 = x ...
# 927    [x + y = z, 3x + 2(y-3) = 91.50, 5x - 6 = 91.5...
# 928    [x + y = 64, 2x + 7 = 7y, 2x = 7y - 7, x = (7/...
# 929    [Downstream speed = Rb + Rc, 72 = 3(Rb + Rc), ...
# 930    [$11.25/hour * 40 hours = $450, $16/hour * x h...
# 931    [t = d / 32, t = d / 10, d/32 + d/10 = 6.3, (5...
# 932    [x+y=14, 10y+x=10x+y-18, 9y-9x=-18, y-x=-2, 2y...
# 933                    [x + y = 80, 4.25x + 1.95y = 220]
# 934    [d = 22t, d = 32(2.25 - t), 22t = 32(2.25 - t)...
# 935    [x * $2.95 + ((30-x) * $3.10) = $90, 2.95x + 9...
# 936    [x = amount of 10% solution, volume of mixture...
# 937                 [2(4+3x)=34, 4+3x=15, 3x=11, x=11/3]
# 938         [200 - x = y, 8x + 10y = 8.75 * 200, x = 50]
# 939    [4x - 19 = 73, 4x = 73 + 19, 4x = 92, x = 92/4...
# 940    [q + d = 100, 0.25q + 0.10d = 19.75, 25q + 10d...
# 941    [0.25x / x + 100 = 0.10, 0.25x = 0.10(x + 100)...
# 942    [x = (1/2)(x + 2) + 5, x = (x/2) + 1 + 5, x = ...
# 943    [7x + 10y = 58.50, 7x + 5y = 39.75, 7x = 39.75...
# 944    [x + y = 24, 20x + 5y = 285, x = 24 - y, 20(24...
# 945    [y=6x-2, x+y=25, x+(6x-2)=25, 7x-2=25, 7x=27, ...
# 946    [0.15(121) = 0.10x + 0.21(121-x), 18.15 = 0.10...
# 947    [1A + 1O = 185, 2A + 3O = 452, A = 185 - O, 2(...
# 948    [x = amount of water needed, 0.8 = 0.4 × 2 = i...
# 949    [0.25q + 0.05n = 2.20, q + n = 12, q = 12 - n,...
# 950            [F = 2D, F-10 = 3(D-10), 2D-10 = 3(D-10)]
# 951    [Cost_A = $5 + $0.35/km * distance, Cost_B = $...
# 952    [width = x, length = 3x + 7.6, perimeter = 2(l...
# 953    [y = 50 + 0.35(x - 500), y = 75 + 0.45(x - 100...
# 954    [4x + 9y = 1/2, 12x + 12y = 1, 12x = 1 - 12y, ...
# 955    [0.14x + 0.45y = 0.30(100), x + y = 100, 0.14x...
# 956    [x + y = 36, 0.18x + 0.09y = 4.68, -0.09y = -0...
# 957    [R + B = 155, R / 10 + B / 29 = 6, R = 155 - B...
# 958    [2(x + 3) + 2x = 100, 4x + 6 = 100, 4x = 94, x...
# 959    [10x + y = 6(x + y), x = y + 1, 10(y + 1) + y ...
# 960    [1/T = 1/S + 1/J, S = 4, J = 6, 1/T = 1/4 + 1/...
# 961    [w + 3 = length, 2(length + width) = 4w + 6, 4...
# 962    [J = 3, T = 6, 1 / x = (1/3) + (1/6), 1 / x = ...
# 963               [x + y = 7, x - y = -3, 9x - 9y = -27]
# 964    [3x + 4y = 43, 5x = -4y - 3, 5x + 4y = -3, 3x ...
# 965    [2x + (x - 16) = -32 - x, 3x - 16 = -32 - x, 4...
# 966    [10x + 20(50 - x) = 800, 10x + 1000 - 20x = 80...
# 967    [x = years ago that Clara was three times Anna...
# 968     [x + (x+28) = 62, 2x + 28 = 62, 2x = 34, x = 17]
# 969                       [3n - 6 = 45, 3n = 51, n = 17]
# 970    [C - D = 7.5, C + D = 114.7, C = D + 7.5, (D +...
# 971               [x + (2x + 3) = 9, 3x + 3 = 9, 3x = 6]
# 972    [6q : 1000m = xq : 2500m, 6q * 2500m = 1000m *...
# 973    [3d + 150m = 132, 2d + 400m = 142, d = (132 - ...
# 974    [0.6x + 0.3y = 0.5(630), 0.6x + 0.3y = 315, x ...
# 975    [x + y = 120, x - y = 42, 2x = 162, x = 81, y ...
# 976    [x + (x + 1) = 27, 2x + 1 = 27, 2x = 26, x = 1...
# 977          [x + 3(x+1) = 39, x + 3x + 3 = 39, 4x = 36]
# 978    [40x + 16y = 26, 30x + 25y = 26, 16y = 26 - 40...
# 979    [x - 15 = 0.8333333x, x - 0.8333333x - 15 = 0,...
# 980    [x = 22, 4 + x = 0.5(30 + x), 4 + x = 15 + 0.5...
# 981    [0.65x + 2.4 = 0.38(x + 12), 0.27x = 2.16, x = 8]
# 982    [x + (x + 32) = 180, 2x + 32 = 180, 2x = 148, ...
# 983    [0.16(x-500)+0.10x=0.76, x-500+x=500+x, 2x-500...
# 984                                      [20+x=75, x=55]
# 985    [x - 13 / 3 - (x + 3) / 5 = 0, 5(x - 13) - 3(x...
# 986    [0.04(4) + 0.1x = 0.06(4 + x), 0.16 + 0.1x = 0...
# 987    [x + 10 = speed of the other train, 1.6x = dis...
# 988    [P = x + 2.10, P = x + 2.00, x + 2.10 = x + 2....
# 989    [1/3(10a+b) - 1/4(10a+b+1) = 1, 4(10a+b) - 3(1...
# 990    [75 = 30 + 45, time = distance ÷ speed, time =...
# 991    [0.8x + 0.3(40-x) = 0.5(40), 0.8x + 12 - 0.3x ...
# 992    [S - 5 = 4(J - 5), s = 2(j + 5), S = 4J - 15, ...
# 993    [y = 2x - 5, x + y = 28, x + (2x - 5) = 28, 3x...
# 994    [time = (work) / (rate), W = 1, R = W / (8 * 1...
# 995    [0.8x = discount price, profit = 0.3 * cost, x...
# 996    [1560 = 1860 - 300, 300 + 50d = 1860 - 70d, 12...
# 997                     [5x = 3x + 3 + 3, 2x = 6, x = 3]
# 998    [80 = x * t, 30 = (x+10) * 1, 80 = x * t, 30 =...
# 999    [x + (x+2) = 124, 2x + 2 = 124, 2x = 122, x = ...
# Name: equations, dtype: object

# %%
# ------------------------------------------- #
#   A helper function for comparing  
#   ChatGPT's response to the actual solution
# ------------------------------------------- #
def evaluate_response(actual_solution, response_solution, transform_func):
    actual_solution = [transform_func(float(solution)) for solution in actual_solution]
    response_solution = [transform_func(float(solution)) for solution in response_solution]

    actual_solution = set(actual_solution)
    response_solution = set(response_solution)
    
    if actual_solution.issubset(response_solution): return "all"
    elif actual_solution.intersection(response_solution): return "some"
    else: return "none"

def count_symbols(text, symbol): return str(text).count(symbol)

# ------------------------------------------- #
#   A function that extracts decimal numbers
#   from string
# ------------------------------------------- #
def extract_decimals(response : str):
    response = str(response)
    pattern = r'\d+(?:\.\d+)?'
    decimals = re.findall(pattern, response)
    decimals = [float(decimal) for decimal in decimals]
    return set(decimals)

features_df = canonicalized_df.copy()
features_df["extracted_solved_ans"] = features_df.apply(lambda row : extract_decimals(row["solved_ans"]), axis=1)
features_df["extracted_final_answer"] = features_df.apply(lambda row : extract_decimals(row["answers"]), axis=1)
features_df["normal_correct"] = features_df.apply(lambda row : evaluate_response(row["ground_solution"], row["extracted_final_answer"], lambda x : x), axis=1) 
features_df["rounded_correct"] = features_df.apply(lambda row : evaluate_response(row["ground_solution"], row["extracted_final_answer"], lambda x : round(x, 1)), axis=1)
features_df["final_solved_same"] = features_df.apply(lambda row : 1 if len(row["extracted_final_answer"].intersection(row["extracted_solved_ans"])) > 0 else 0, axis=1)

answer_map = {"all": 1, "some" : 1, "none": 0}
features_df['is_correct'] = features_df.apply(lambda row : answer_map[row["normal_correct"]], axis=1)
features_df["num_of_additions"] = features_df.apply(lambda row : count_symbols(row["equations"], '+'), axis=1)
features_df["num_of_subtractions"] = features_df.apply(lambda row : count_symbols(row["equations"], '-'), axis=1)
features_df["num_of_multiplications"] = features_df.apply(lambda row : count_symbols(row["equations"], '*'), axis=1)
features_df["num_of_divisions"] = features_df.apply(lambda row : count_symbols(row["equations"], '/'), axis=1)
features_df["num_of_equations"] = features_df.apply(lambda row : count_symbols(row["equations"], '='), axis=1)
features_df["num_of_parentheses"] = features_df.apply(lambda row : count_symbols(row["equations"], '('), axis=1)

features_df.head(3)
# Out:
#    ground_solution                                           response  \
# 0     [83.0, 78.0]  \n\nLet x be the number of three-legged stools...
# 1  [2.14285714286]  \n\nLet's call the speed of the current 'c'. \...
# 2         [1155.0]  \n\nTo calculate the number of students, we ne...
#
#                                            equations       answers  \
# 0  [x + y = 161, 3x + 4y = 566, x = 161 - y, 3(16...  [78.0, 83.0]
# 1  [speed downstream = 15 + c, speed upstream = 1...        [2.14]
# 2               [a = b x c, a = 42 x 27.5, a = 1155]      [1155.0]
#
#                              canonicalized_equations  \
# 0  [a + b = 161, 3a + 4b = 566, a = 161 - b, 3(16...
# 1  [c = 15 + g, e = 15 - g, d = f, a / c = b / e,...
# 2  [if=fafdfg, if=f4hfdfhb[@!#@!#@!#!@#!@#@!#!@$#...
#
#                                      solved_ans  \
# 0                                {a: 78, b: 83}
# 1  {g: 15/7, e: 90/7, c: 120/7, a: 4*b/3, d: f}
# 2                                            {}
#
#                  extracted_solved_ans extracted_final_answer normal_correct  \
# 0                        {83.0, 78.0}           {83.0, 78.0}            all
# 1  {3.0, 4.0, 7.0, 15.0, 120.0, 90.0}                 {2.14}           none
# 2                                  {}               {1155.0}            all
#
#   rounded_correct  final_solved_same  is_correct  num_of_additions  \
# 0             all                  1           1                 5
# 1             all                  0           0                 4
# 2             all                  0           1                 0
#
#    num_of_subtractions  num_of_multiplications  num_of_divisions  \
# 0                    3                       0                 0
# 1                    4                       0                 4
# 2                    0                       0                 0
#
#    num_of_equations  num_of_parentheses
# 0                 8                   1
# 1                 9                   4
# 2                 3                   0

# %%
model_df = features_df[[
    # "num_of_unknowns", 
    "num_of_additions", 
    "num_of_subtractions", 
    "num_of_multiplications", 
    "num_of_divisions", 
    "num_of_equations", 
    "num_of_parentheses", 

    # "final_solved_same",
    "is_correct",
]]
model_df = model_df.dropna()

print("Dataframe LEN:" + str(len(model_df)))
model_df.head()
# Out:
# Dataframe LEN:1000
#    num_of_additions  num_of_subtractions  num_of_multiplications  \
# 0                 5                    3                       0
# 1                 4                    4                       0
# 2                 0                    0                       0
# 3                 3                    0                       0
# 4                 7                    7                       0
#
#    num_of_divisions  num_of_equations  num_of_parentheses  is_correct
# 0                 0                 8                   1           1
# 1                 4                 9                   4           0
# 2                 0                 3                   0           1
# 3                 0                 6                   2           0
# 4                 0                 9                   3           0

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

train, test = train_test_split(model_df, test_size=TEST_SIZE, random_state=RANDOM_STATE)

train_x = train.drop(columns=["is_correct"])
test_x = test.drop(columns=["is_correct"])

# train_x = pandas.DataFrame(scaler.fit_transform(train_x))
# test_x = pandas.DataFrame(scaler.fit_transform(test_x))

train_y = train["is_correct"]
test_y = test[["is_correct"]]

display(train_x.head())
display(train_y.head())
# Out:
#      num_of_additions  num_of_subtractions  num_of_multiplications  \
# 29                  2                    0                       0
# 535                 4                    0                       0
# 695                 2                    0                       0
# 557                 5                    3                       0
# 836                 0                    2                       0
#
#      num_of_divisions  num_of_equations  num_of_parentheses
# 29                  0                 5                   0
# 535                 0                 5                   1
# 695                 0                 8                   1
# 557                 0                 9                   1
# 836                 6                 9                   5
# 29     1
# 535    1
# 695    1
# 557    1
# 836    1
# Name: is_correct, dtype: int64

# %%
# =========================================== #
#    Sklearn Helper
# =========================================== #
class SklearnHelper(object):
    def __init__(self, clf, seed=0, params={}):
        self.clf = clf
        self.params = params

    def fit(self, x_train, y_train):
        self.fitted = self.clf(**self.params).fit(x_train, y_train)
    
    def predict(self, x):
        return self.fitted.predict(x)
    
    def predict_proba(self, x):
        return self.fitted.predict_proba(x)
    
    def feature_importance(self):
        return self.fitted.feature_importances_
    
    def tune(self, x_train, y_train, params=None):
        
        grid = GridSearchCV(self.clf(), param_grid=params)
        grid.fit(x_train, y_train)

        self.params = grid.best_params_

        print(self.params)
        pass

    def get_model(self):
        return self.clf(**self.params)

# %%
# =========================================== #
#    TF Helper
# =========================================== #
class TFHelper(object):
    def __init__(self, clf, seed=0, params={}):
        self.clf = clf

    def fit(self, x_train, y_train):
        self.fitted = self.clf.fit(x_train, y_train, epochs=10, verbose=0)
    
    def predict(self, x):
        return [1 if prediction > 0.5 else 0 for prediction in list(self.clf.predict(x))]
    
    def feature_importance(self):
        return self.fitted.feature_importances_
    
    def tune(self, x_train, y_train, params=None):
        pass

# %%
# =========================================== #
#    Cross-validate models
# =========================================== #
def cross_validate(model, x_data, y_data, n_splits, random_state=42, shuffle=True):
    cross_fold = KFold(n_splits, random_state=random_state, shuffle=shuffle)

    cross_validation_results = []
    for i, (train_index, test_index) in enumerate(cross_fold.split(x_data)):
        x_train, y_train = x_data.iloc[train_index], y_data.iloc[train_index]
        x_test, y_test = x_data.iloc[test_index], y_data.iloc[test_index]

        model.fit(x_train, y_train)
        y_pred = model.predict(x_test)

        report = classification_report(y_test, y_pred, target_names=list(set(answer_map.values())), output_dict=True)
        cross_validation_results.append(report)

    average_results = {}
    for result in cross_validation_results:
        for key1 in list(set(answer_map.values())):
            average_results[key1] = {}
            for key2 in ['precision', 'recall', 'f1-score', 'support']:
                average_results[key1][key2] = 0

    for result in cross_validation_results:
        for key1 in list(set(answer_map.values())):
            for key2 in ['precision', 'recall', 'f1-score', 'support']:
                average_results[key1][key2] += result[key1][key2]
    
    for key1 in list(set(answer_map.values())):
        for key2 in ['precision', 'recall', 'f1-score', 'support']:
            average_results[key1][key2] /= n_splits
        
    return pandas.DataFrame(average_results)

def cross_validate_model(classifier):
    return cross_validate(classifier, train_x, train_y, N_SPLITS, RANDOM_STATE, True)

# %%
results_dict = {}

# %%
# =========================================== #
#    Random Forest
# =========================================== #
random_forest = SklearnHelper(RandomForestClassifier)

random_forest.tune(train_x, train_y, params={
    "random_state" : [RANDOM_STATE],
    'n_jobs': [-1],
    'n_estimators': [100],
    'max_depth': [6],
    'min_samples_leaf': [2],
    'max_features': ['sqrt'],
    'class_weight': ['balanced_subsample']
}
)

random_forest_results = cross_validate_model(random_forest)
results_dict.update(RandomForestClassifier=random_forest_results)
pandas.DataFrame(random_forest_results)
# Out:
# {'class_weight': 'balanced_subsample', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'n_estimators': 100, 'n_jobs': -1, 'random_state': 42}
#                    0           1
# precision   0.486192    0.777442
# recall      0.434848    0.808352
# f1-score    0.453589    0.791374
# support    46.400000  113.600000

# %%
# =========================================== #
#    Extra Trees Classifier
# =========================================== #
extra_trees = SklearnHelper(ExtraTreesClassifier)
extra_trees.tune(train_x, train_y, params={
    "random_state": [RANDOM_STATE],
    'n_jobs': [-1],
    'n_estimators': [100],
    'max_depth': [6],
    'min_samples_leaf': [2],
    'max_features': ['sqrt'],
    'class_weight': ['balanced_subsample']
})
extra_trees_results = cross_validate_model(extra_trees)
results_dict.update(ExtraTreesClassifier=extra_trees_results)
pandas.DataFrame(extra_trees_results)
# Out:
# {'class_weight': 'balanced_subsample', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'n_estimators': 100, 'n_jobs': -1, 'random_state': 42}
#                    0           1
# precision   0.479397    0.782661
# recall      0.461467    0.794325
# f1-score    0.465768    0.787359
# support    46.400000  113.600000

# %%
# =========================================== #
#    XGBoost
# =========================================== #
xgboost = SklearnHelper(XGBClassifier, seed=RANDOM_STATE)
xgboost.tune(train_x, train_y, params={
    "random_state": [RANDOM_STATE],
    'learning_rate': [0.1],
    'n_jobs': [-1],
    'n_estimators': [100],
    'max_depth': [6],
    'subsample': [0.3],
})
xgboost_results = cross_validate_model(xgboost)
results_dict.update(XGBClassifier=xgboost_results)
pandas.DataFrame(xgboost_results)
# Out:
# {'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 100, 'n_jobs': -1, 'random_state': 42, 'subsample': 0.3}
#                    0           1
# precision   0.514202    0.756366
# recall      0.308105    0.879519
# f1-score    0.382232    0.813009
# support    46.400000  113.600000

# %%
# =========================================== #
#    Gradient Boost
# =========================================== #
gradient_boost = SklearnHelper(GradientBoostingClassifier, seed=RANDOM_STATE)
gradient_boost.tune(train_x, train_y, params={
    "random_state" : [RANDOM_STATE],
    'learning_rate': [0.1],
    'n_estimators': [100],
    'max_depth': [6],
    'subsample': [0.3],
})
gradient_boost_results = cross_validate_model(gradient_boost)
results_dict.update(GradientBoostingClassifier=gradient_boost_results)
pandas.DataFrame(gradient_boost_results)
# Out:
# {'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 100, 'random_state': 42, 'subsample': 0.3}
#                    0           1
# precision   0.462618    0.756906
# recall      0.343235    0.836453
# f1-score    0.390534    0.793968
# support    46.400000  113.600000

# %%
# # =========================================== #
# #    Gradient Boost
# # =========================================== #
# k_neighbors = SklearnHelper(KNeighborsClassifier, seed=RANDOM_STATE)
# k_neighbors.tune(train_x, train_y, params={
#     "n_neighbors": [5],
#     "weights": ['uniform'],
#     "algorithm": ['auto'],
#     'leaf_size': [10],
#     'p': [2]
# })
# k_neighbors_results = cross_validate_model(k_neighbors)
# results_dict.update(KNeighborsClassifier=k_neighbors_results)
# pandas.DataFrame(k_neighbors_results)

# %%
# =========================================== #
#    Ada Boost
# =========================================== #
adaboost = SklearnHelper(AdaBoostClassifier, seed=RANDOM_STATE)
adaboost.tune(train_x, train_y, params={
    "random_state" : [RANDOM_STATE],
    'learning_rate': [0.1],
    'n_estimators': [100],
})
adaboost_results = cross_validate_model(adaboost)
results_dict.update(AdaBoostClassifier=adaboost_results)
pandas.DataFrame(adaboost_results)
# Out:
# {'learning_rate': 0.1, 'n_estimators': 100, 'random_state': 42}
#                    0           1
# precision   0.610317    0.737158
# recall      0.165064    0.956162
# f1-score    0.254106    0.832054
# support    46.400000  113.600000

# %%
# =========================================== #
#    Ada Boost
# =========================================== #
mlp = SklearnHelper(MLPClassifier, seed=RANDOM_STATE)
mlp.tune(train_x, train_y, params={
    'hidden_layer_sizes': [(64, 32, 16, 8, 4)],
    'max_iter': [1000]
})
mlp_results = cross_validate_model(mlp)
results_dict.update(MLPClassifier=adaboost_results)
pandas.DataFrame(adaboost_results)
# Out:
# {'hidden_layer_sizes': (64, 32, 16, 8, 4), 'max_iter': 1000}
#                    0           1
# precision   0.610317    0.737158
# recall      0.165064    0.956162
# f1-score    0.254106    0.832054
# support    46.400000  113.600000

# %%
estimators = [
    ('rf', random_forest.get_model()),
    ('xgb', xgboost.get_model()),
    ('knn', k_neighbors.get_model()),
    ('ab', adaboost.get_model())
]

lgclassifier = AdaBoostClassifier(random_state=RANDOM_STATE)

stacked = SklearnHelper(StackingClassifier, params={
    "estimators": estimators,
    "final_estimator": lgclassifier,
    "cv": 5})


stacked_results = cross_validate_model(stacked)
results_dict.update(StackingClassifier=stacked_results)
pandas.DataFrame(stacked_results)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23432\3721987168.py in <module>
#       2     ('rf', random_forest.get_model()),
#       3     ('xgb', xgboost.get_model()),
# ----> 4     ('knn', k_neighbors.get_model()),
#       5     ('ab', adaboost.get_model())
#       6 ]
#
# NameError: name 'k_neighbors' is not defined

# %%
n = len(train_x.columns)

sequential_model = keras.Sequential(
    [
        tf.keras.layers.Dense(64, activation='relu'),
        tf.keras.layers.Dense(32, activation='relu'),
        tf.keras.layers.Dense(16, activation='relu'),
        tf.keras.layers.Dense(8, activation='relu'),
        tf.keras.layers.Dense(1, activation='sigmoid')
    ]
)

sequential_model.compile(
    optimizer='adam', loss='binary_crossentropy', metrics=['accuracy']
)

sequential_model = TFHelper(sequential_model)
sequential_model_results = cross_validate_model(sequential_model)
results_dict.update(TF_Five_Layers=sequential_model_results)
sequential_model_results
# Out:
# 5/5 [==============================] - 0s 1ms/step
# 5/5 [==============================] - 0s 2ms/step
# 5/5 [==============================] - 0s 2ms/step
# 5/5 [==============================] - 0s 1ms/step
# 5/5 [==============================] - 0s 2ms/step
#                    0          1
# precision   0.829193   0.931475
# recall      0.903919   0.878639
# f1-score    0.863408   0.903626
# support    63.600000  96.400000

# %%
# %load causality_analysis/calculate_causality.py
import pandas as pd

MAX_NAME_DIFFERENCE = 3

class Causality:
    @staticmethod
    def causality_wrapper(input_df, VALID_COLUMN, EFFECT_COLUMN):
        def negation(column):
            # negation -- 
            # OUTPUT: returns a column of 0s and 1s of the negation of [column]. 1s are flipped to 0 and vice versa
            # INPUT: [column] should be a column of 0s and 1s
            return 1 - column
            
            """"""
        def conjunction(column_1, column_2):
            # conjunction -- 
            # output: returns a column of 0s and 1s of the conjunction between [column_1] and [column_2].
            # INPUT: [column_1] and [column_2] should be columns of 0s and 1s
            return column_1 * column_2
            
            """"""
        def disjunction(column_1, column_2):
            # disjunction -- 
            # OUTPUT: returns a column of 0s and 1s of the disjunction between [column_1] and [column_2].
            # INPUT: [column_1] and [column_2] should be columns of 0s and 1s
            return column_1 | column_2
            
            """"""
        def conditional_probability(occurence_column, condition_column):
            # conditional_probability -- 
            # OUTPUT: returns a number which represents the conditional probability p(occurence | condition)
            # INPUT: [occurence_column] and [condition_column] should be columns of 0s and 1s
            if condition_column.sum() == 0: return 0
            return conjunction(occurence_column, condition_column).sum() / condition_column.sum()
            
            """"""
        def prior(data):
            # prior -- 
            # OUTPUT: returns a number which represents the prior
            # INPUT: [data] should be a Pandas dataframe with the columns [CORRECT_COLUMN] and [VALID_COLUMN].
            # TODO : Possible optimizations can be made where we cache the result instead of calling this expensive operation again and again
            return conditional_probability(data[EFFECT_COLUMN], data[VALID_COLUMN])
            
            """"""
        def is_prima_facie(data, column_name):
            # is_prima_facie -- 
            # OUTPUT: returns a boolean which determines whether the column indicated by [column_name] is a prima facie
            # INPUT: [data] should be a Pandas dataframe with the columns [CORRECT_COLUMN] and [VALID_COLUMN].
            # INPUT: [column_name] should be a valid column in [data]
            # INPUT: The [CORRECT_COLUMN] and [VALID_COLUMN] columns should be columns of 0s and 1s 
            return conditional_probability(data[EFFECT_COLUMN], data[column_name]) - prior(data) > 0
            
            """"""
        def is_cooccur(column_1, column_2):
            # is_cooccur -- 
            # OUTPUT: returns a boolean based on if there is at least one row where both [column_1] and [column_2] is equal to 1
            # INPUT: [column_1] and [column_2] should both be columns of 0s and 1s
            return conjunction(column_1, column_2).sum() > 0
            
            """"""
        def is_same_category(column_name_1, column_name_2):
            # same_category -- 
            # OUTPUT: Returns a boolean signifying whether the [column_name_1] and [column_name_2] are different by [MAX_NAME_DIFFERENCE]
            #         If the two words are not different by [MAX_NAME_DIFFERENCE], they are in the same category so it returns true
            count = 0
            shortest = min(len(column_name_1), len(column_name_2))
            for i in range(0, shortest):
                if column_name_1[i] == column_name_2[i]:
                    count = count + 1
            return max(len(column_name_1), len(column_name_2)) - count < MAX_NAME_DIFFERENCE
            
            """"""
        def rel(data, column_name):
            # rel -- 
            # OUTPUT: returns a list of the names of other columns which cooccur with [column_name] and are prima facie
            # INPUT: [data] should be a Pandas dataframe with the columns [CORRECT_COLUMN] and [VALID_COLUMN].
            # INPUT: [column_name] should be a valid column in [data]
            # INPUT: The [CORRECT_COLUMN] and [VALID_COLUMN] columns should be columns of 0s and 1s 
            
            # # If it is not a prima facie cause, we don't bother to find its rel
            if not is_prima_facie(data,column_name): return[]
                
            if column_name in [VALID_COLUMN, EFFECT_COLUMN]: return []
            
            name_list = []
            for potential_cause in data.columns:
                # Make sure we are not including the [CORRECT_COLUMN] and [VALID_COLUMN] as part of rel
                if potential_cause in [EFFECT_COLUMN, VALID_COLUMN, column_name]: continue

                # if is_same_category(potential_cause, column_name): continue

                if is_cooccur(data[column_name], data[potential_cause]) and is_prima_facie(data, potential_cause):
                    name_list.append(potential_cause)
            return name_list
            
            """"""
        def calculate_causality(data, column_name):
            # calculate_causality -- 
            # OUTPUT: returns a number which represents the causality value of the column indicated by [column_name]
            # INPUT: [data] should be a Pandas dataframe with the columns [CORRECT_COLUMN].
            # INPUT: [column_name] should be a valid column in [data]
            # INPUT: The [CORRECT_COLUMN] and [VALID_COLUMN] columns should be columns of 0s and 1s 

            # If it's not a prima facie cause, we don't bother to calculate its causality value
            if not is_prima_facie(data, column_name):
                return "n/a"

            relateds = rel(data, column_name)
            total_probability = 0
            for related in relateds:
                conj = conjunction(data[column_name], data[related])
                negj = conjunction(negation(data[column_name]), data[related])

                k = data[column_name].sum() / len(data)
                conj = conditional_probability(data[EFFECT_COLUMN], conj)
                negj = conditional_probability(data[EFFECT_COLUMN], negj)

                # total_probability += k * (conj - negj)
                total_probability += (conj - negj)

            if (len(relateds) > 0): return total_probability / len(relateds)
            return total_probability
            
            """"""
        def is_binary_column(data, column_name):
            # is_binary_column --
            # Checks to see if a column is a column of 1s and 0s
            # INPUT: [data] is a dataframe
            # INPUT: [column_name] should be the name of a valid column in [data]
            return data.apply(lambda row : 0 if (isinstance(row[column_name], int) and (row[column_name] <= 1)) else 1, axis=1).sum() <= 0
            
            """"""
        def remove_non_binary_columns(data):
            # remove_non_binary_columns --
            # Removes all columns that are not 0s or 1s in the dataset
            # INPUT: [data] is a dataframe
            non_binary = []
            for i in data.columns:
                if i in [EFFECT_COLUMN, VALID_COLUMN]: continue
                if not is_binary_column(data, i):
                    non_binary.append(i)

            return data.drop(columns=non_binary)
            
            """"""
        def generate_row(data, column_name):
            # generate_row --
            # TODO: This is kind of a terrible name but I can't really think of anything more descriptive. If anyone has any ideas, feel free to modify it
            # It basically creates a row, which is actually a data frame with all the data that is needed
            # OUTPUT: It outputs a row with all the required values
            # INPUT: [data] should be a dataframe
            # INPUT: [column_name] should be a string representing a valid column in [data]
            toReturn = pd.DataFrame({
                "name": [column_name], 
                "support": conjunction(data[column_name], data[VALID_COLUMN]).sum(),
                "causality": [calculate_causality(data, column_name)],
                "rel": ','.join(rel(data, column_name)),
                "conditional_probability":[conditional_probability(data[EFFECT_COLUMN], data[column_name])], 
                "prior": prior(data),
                "conditional - prior": conditional_probability(data[EFFECT_COLUMN], data[column_name]) - prior(data)
            })
            return toReturn
            
            """"""

        def causality_values(input_df):
            # causality_values --
            # Calculates causality values

            # Then remove all the non binary columns
            # input_df = remove_non_binary_columns(input_df)

            # TODO: This is a hack
            # short_names = []
            # for column in input_df.columns:
            #     if len(column) < 5 and column != VALID_COLUMN and column != EFFECT_COLUMN: short_names.append(column)
            # input_df = input_df.drop(columns=short_names, axis=1)

            # TODO: I'm not sure if there's another way to do this, so feel free to make modifications
            # Generate a dud data frame with a single so we can append to it.
            to_save = generate_row(input_df, VALID_COLUMN)
            for column in input_df.columns:
                if column in [VALID_COLUMN, EFFECT_COLUMN]: continue
                to_save = to_save.append(generate_row(input_df, column))

            # Remove the dud first row
            to_save = to_save[1:]
            return to_save

            """"""

        to_return = causality_values(input_df)
        return to_return

# %%
def generate_geq_column(dataframe, column_name):
    i = 1
    while True:
        res = dataframe.apply(lambda row : 1 if row[column_name] >= i else 0, axis=1)
        if res.sum() == 0: break
        dataframe[f"{column_name}_geq_{i}"] = res
        i += 1
    return dataframe

def generate_geq_columns(dataframe, column_names):
    for column_name in column_names:
        dataframe = generate_geq_column(dataframe, column_name)
    return dataframe

causality_df = model_df.copy()
causality_df["is_correct"] = causality_df.apply(lambda row : 1 - row["is_correct"], axis=1)
causality_df["final_solved_different"] = causality_df.apply(lambda row : 1 - row["final_solved_same"], axis=1)
causality_df = causality_df.drop(columns=["final_solved_same"])

causality_df["num_of_additions_and_subtractions"] = causality_df["num_of_additions"] + causality_df["num_of_subtractions"]
causality_df["num_of_divisions_and_multiplications"] = causality_df["num_of_divisions"] + causality_df["num_of_multiplications"]
causality_df = generate_geq_columns(causality_df, [
    "num_of_additions_and_subtractions", 
    "num_of_divisions_and_multiplications", 
    "num_of_multiplications", 
    "num_of_divisions", 
    "num_of_equations", 
    "num_of_parentheses", 
])

causality_df = causality_df.drop(columns=[
    "num_of_additions_and_subtractions", 
    "num_of_divisions_and_multiplications", 
    "num_of_additions",
    "num_of_subtractions",
    "num_of_multiplications", 
    "num_of_divisions", 
    "num_of_equations", 
    "num_of_parentheses", 
])

causality_df['valid'] = 1
causality_df = Causality.causality_wrapper(causality_df, 'valid', 'is_correct')
causality_df
# Out:
#                                           name  support causality  \
# 0                       final_solved_different      445   0.91002
# 0      num_of_additions_and_subtractions_geq_1      975       n/a
# 0      num_of_additions_and_subtractions_geq_2      903       n/a
# 0      num_of_additions_and_subtractions_geq_3      764       n/a
# 0      num_of_additions_and_subtractions_geq_4      658       n/a
# 0      num_of_additions_and_subtractions_geq_5      553       n/a
# 0      num_of_additions_and_subtractions_geq_6      466       n/a
# 0      num_of_additions_and_subtractions_geq_7      346       n/a
# 0      num_of_additions_and_subtractions_geq_8      243  0.539773
# 0      num_of_additions_and_subtractions_geq_9      145  0.520651
# 0     num_of_additions_and_subtractions_geq_10      101  0.519584
# 0     num_of_additions_and_subtractions_geq_11       70  0.537688
# 0     num_of_additions_and_subtractions_geq_12       51  0.563805
# 0     num_of_additions_and_subtractions_geq_13       34  0.578201
# 0     num_of_additions_and_subtractions_geq_14       27  0.591617
# 0     num_of_additions_and_subtractions_geq_15       15  0.597542
# 0     num_of_additions_and_subtractions_geq_16       10  0.646382
# 0     num_of_additions_and_subtractions_geq_17        8  0.619368
# 0     num_of_additions_and_subtractions_geq_18        6  0.597916
# 0     num_of_additions_and_subtractions_geq_19        5  0.602233
# 0     num_of_additions_and_subtractions_geq_20        3  0.676833
# 0     num_of_additions_and_subtractions_geq_21        2  0.669269
# 0     num_of_additions_and_subtractions_geq_22        2  0.669269
# 0     num_of_additions_and_subtractions_geq_23        1  0.648403
# 0     num_of_additions_and_subtractions_geq_24        1  0.648403
# 0     num_of_additions_and_subtractions_geq_25        1  0.648403
# 0     num_of_additions_and_subtractions_geq_26        1  0.648403
# 0     num_of_additions_and_subtractions_geq_27        1  0.648403
# 0     num_of_additions_and_subtractions_geq_28        1  0.648403
# 0     num_of_additions_and_subtractions_geq_29        1  0.648403
# 0     num_of_additions_and_subtractions_geq_30        1  0.648403
# 0     num_of_additions_and_subtractions_geq_31        1  0.648403
# 0     num_of_additions_and_subtractions_geq_32        1  0.648403
# 0     num_of_additions_and_subtractions_geq_33        1  0.648403
# 0     num_of_additions_and_subtractions_geq_34        1  0.648403
# 0     num_of_additions_and_subtractions_geq_35        1  0.648403
# 0     num_of_additions_and_subtractions_geq_36        1  0.648403
# 0     num_of_additions_and_subtractions_geq_37        1  0.648403
# 0     num_of_additions_and_subtractions_geq_38        1  0.648403
# 0     num_of_additions_and_subtractions_geq_39        1  0.648403
# 0     num_of_additions_and_subtractions_geq_40        1  0.648403
# 0     num_of_additions_and_subtractions_geq_41        1  0.648403
# 0     num_of_additions_and_subtractions_geq_42        1  0.648403
# 0     num_of_additions_and_subtractions_geq_43        1  0.648403
# 0     num_of_additions_and_subtractions_geq_44        1  0.648403
# 0     num_of_additions_and_subtractions_geq_45        1  0.648403
# 0     num_of_additions_and_subtractions_geq_46        1  0.648403
# 0   num_of_divisions_and_multiplications_geq_1      267  0.516455
# 0   num_of_divisions_and_multiplications_geq_2      215  0.514126
# 0   num_of_divisions_and_multiplications_geq_3      166  0.491456
# 0   num_of_divisions_and_multiplications_geq_4      133  0.438621
# 0   num_of_divisions_and_multiplications_geq_5      101  0.417744
# 0   num_of_divisions_and_multiplications_geq_6       77  0.421688
# 0   num_of_divisions_and_multiplications_geq_7       62  0.415555
# 0   num_of_divisions_and_multiplications_geq_8       51  0.399703
# 0   num_of_divisions_and_multiplications_geq_9       38  0.359964
# 0  num_of_divisions_and_multiplications_geq_10       31  0.331341
# 0  num_of_divisions_and_multiplications_geq_11       26  0.311466
# 0  num_of_divisions_and_multiplications_geq_12       18  0.166141
# 0  num_of_divisions_and_multiplications_geq_13        7  0.070363
# 0  num_of_divisions_and_multiplications_geq_14        5  0.075145
# 0  num_of_divisions_and_multiplications_geq_15        5  0.075145
# 0  num_of_divisions_and_multiplications_geq_16        4  0.196145
# 0  num_of_divisions_and_multiplications_geq_17        1  0.299243
# 0                 num_of_multiplications_geq_1       75  0.139866
# 0                 num_of_multiplications_geq_2       51  0.109781
# 0                 num_of_multiplications_geq_3       27  0.042784
# 0                 num_of_multiplications_geq_4       11  0.046417
# 0                 num_of_multiplications_geq_5        5  0.047954
# 0                 num_of_multiplications_geq_6        2 -0.280585
# 0                 num_of_multiplications_geq_7        1  0.398244
# 0                 num_of_multiplications_geq_8        1  0.398244
# 0                 num_of_multiplications_geq_9        1  0.398244
# 0                       num_of_divisions_geq_1      232  0.413976
# 0                       num_of_divisions_geq_2      183  0.415164
# 0                       num_of_divisions_geq_3      140  0.298539
# 0                       num_of_divisions_geq_4      112  0.271504
# 0                       num_of_divisions_geq_5       87  0.269747
# 0                       num_of_divisions_geq_6       66  0.323832
# 0                       num_of_divisions_geq_7       54  0.291411
# 0                       num_of_divisions_geq_8       45  0.280905
# 0                       num_of_divisions_geq_9       36   0.30773
# 0                      num_of_divisions_geq_10       27   0.26798
# 0                      num_of_divisions_geq_11       22  0.367039
# 0                      num_of_divisions_geq_12       16  0.259646
# 0                      num_of_divisions_geq_13        5  0.125451
# 0                      num_of_divisions_geq_14        3  0.151077
# 0                      num_of_divisions_geq_15        3  0.151077
# 0                      num_of_divisions_geq_16        2  0.387212
# 0                       num_of_equations_geq_1      994       n/a
# 0                       num_of_equations_geq_2      992       n/a
# 0                       num_of_equations_geq_3      952  0.709442
# 0                       num_of_equations_geq_4      873  0.428827
# 0                       num_of_equations_geq_5      713  0.390453
# 0                       num_of_equations_geq_6      619  0.362865
# 0                       num_of_equations_geq_7      511  0.372489
# 0                       num_of_equations_geq_8      392       n/a
# 0                       num_of_equations_geq_9      252   0.40591
# 0                      num_of_equations_geq_10      127  0.373184
# 0                      num_of_equations_geq_11       63  0.357289
# 0                      num_of_equations_geq_12       36  0.322227
# 0                      num_of_equations_geq_13       22  0.407041
# 0                      num_of_equations_geq_14       14   0.41525
# 0                      num_of_equations_geq_15        6  0.471663
# 0                      num_of_equations_geq_16        1  0.648403
# 0                      num_of_equations_geq_17        1  0.648403
# 0                      num_of_equations_geq_18        1  0.648403
# 0                      num_of_equations_geq_19        1  0.648403
# 0                      num_of_equations_geq_20        1  0.648403
# 0                      num_of_equations_geq_21        1  0.648403
# 0                      num_of_equations_geq_22        1  0.648403
# 0                      num_of_equations_geq_23        1  0.648403
# 0                      num_of_equations_geq_24        1  0.648403
# 0                      num_of_equations_geq_25        1  0.648403
# 0                      num_of_equations_geq_26        1  0.648403
# 0                      num_of_equations_geq_27        1  0.648403
# 0                     num_of_parentheses_geq_1      714       n/a
# 0                     num_of_parentheses_geq_2      348  0.503368
# 0                     num_of_parentheses_geq_3      153  0.455098
# 0                     num_of_parentheses_geq_4       90  0.466583
# 0                     num_of_parentheses_geq_5       49    0.4349
# 0                     num_of_parentheses_geq_6       28  0.396645
# 0                     num_of_parentheses_geq_7       17   0.40675
# 0                     num_of_parentheses_geq_8       13  0.590453
# 0                     num_of_parentheses_geq_9        6  0.626213
# 0                    num_of_parentheses_geq_10        6  0.626213
# 0                    num_of_parentheses_geq_11        4  0.583949
# 0                    num_of_parentheses_geq_12        4  0.583949
# 0                    num_of_parentheses_geq_13        2  0.377608
# 0                    num_of_parentheses_geq_14        2  0.377608
# 0                    num_of_parentheses_geq_15        1  0.344636
# 0                    num_of_parentheses_geq_16        1  0.344636
# 0                    num_of_parentheses_geq_17        1  0.344636
#
#                                                  rel  conditional_probability  \
# 0  num_of_additions_and_subtractions_geq_8,num_of...                 0.831461
# 0                                                                    0.393846
# 0                                                                    0.379845
# 0                                                                    0.366492
# 0                                                                    0.352584
# 0                                                                    0.358047
# 0                                                                    0.356223
# 0                                                                    0.375723
# 0  final_solved_different,num_of_additions_and_su...                 0.411523
# 0  final_solved_different,num_of_additions_and_su...                 0.434483
# 0  final_solved_different,num_of_additions_and_su...                 0.465347
# 0  final_solved_different,num_of_additions_and_su...                 0.571429
# 0  final_solved_different,num_of_additions_and_su...                 0.666667
# 0  final_solved_different,num_of_additions_and_su...                 0.705882
# 0  final_solved_different,num_of_additions_and_su...                 0.740741
# 0  final_solved_different,num_of_additions_and_su...                 0.933333
# 0  final_solved_different,num_of_additions_and_su...                 0.900000
# 0  final_solved_different,num_of_additions_and_su...                 0.875000
# 0  final_solved_different,num_of_additions_and_su...                 0.833333
# 0  final_solved_different,num_of_additions_and_su...                 0.800000
# 0  final_solved_different,num_of_additions_and_su...                 1.000000
# 0  final_solved_different,num_of_additions_and_su...                 1.000000
# 0  final_solved_different,num_of_additions_and_su...                 1.000000
# 0  final_solved_different,num_of_additions_and_su...                 1.000000
# 0  final_solved_different,num_of_additions_and_su...                 1.000000
# 0  final_solved_different,num_of_additions_and_su...                 1.000000
# 0  final_solved_different,num_of_additions_and_su...                 1.000000
# 0  final_solved_different,num_of_additions_and_su...                 1.000000
# 0  final_solved_different,num_of_additions_and_su...                 1.000000
# 0  final_solved_different,num_of_additions_and_su...                 1.000000
# 0  final_solved_different,num_of_additions_and_su...                 1.000000
# 0  final_solved_different,num_of_additions_and_su...                 1.000000
# 0  final_solved_different,num_of_additions_and_su...                 1.000000
# 0  final_solved_different,num_of_additions_and_su...                 1.000000
# 0  final_solved_different,num_of_additions_and_su...                 1.000000
# 0  final_solved_different,num_of_additions_and_su...                 1.000000
# 0  final_solved_different,num_of_additions_and_su...                 1.000000
# 0  final_solved_different,num_of_additions_and_su...                 1.000000
# 0  final_solved_different,num_of_additions_and_su...                 1.000000
# 0  final_solved_different,num_of_additions_and_su...                 1.000000
# 0  final_solved_different,num_of_additions_and_su...                 1.000000
# 0  final_solved_different,num_of_additions_and_su...                 1.000000
# 0  final_solved_different,num_of_additions_and_su...                 1.000000
# 0  final_solved_different,num_of_additions_and_su...                 1.000000
# 0  final_solved_different,num_of_additions_and_su...                 1.000000
# 0  final_solved_different,num_of_additions_and_su...                 1.000000
# 0  final_solved_different,num_of_additions_and_su...                 1.000000
# 0  final_solved_different,num_of_additions_and_su...                 0.715356
# 0  final_solved_different,num_of_additions_and_su...                 0.744186
# 0  final_solved_different,num_of_additions_and_su...                 0.746988
# 0  final_solved_different,num_of_additions_and_su...                 0.736842
# 0  final_solved_different,num_of_additions_and_su...                 0.742574
# 0  final_solved_different,num_of_additions_and_su...                 0.766234
# 0  final_solved_different,num_of_additions_and_su...                 0.790323
# 0  final_solved_different,num_of_additions_and_su...                 0.803922
# 0  final_solved_different,num_of_additions_and_su...                 0.789474
# 0  final_solved_different,num_of_additions_and_su...                 0.774194
# 0  final_solved_different,num_of_additions_and_su...                 0.769231
# 0  final_solved_different,num_of_additions_and_su...                 0.722222
# 0  final_solved_different,num_of_additions_and_su...                 0.571429
# 0  final_solved_different,num_of_additions_and_su...                 0.600000
# 0  final_solved_different,num_of_additions_and_su...                 0.600000
# 0  final_solved_different,num_of_additions_and_su...                 0.750000
# 0  final_solved_different,num_of_divisions_and_mu...                 1.000000
# 0  final_solved_different,num_of_additions_and_su...                 0.733333
# 0  final_solved_different,num_of_additions_and_su...                 0.784314
# 0  final_solved_different,num_of_additions_and_su...                 0.740741
# 0  final_solved_different,num_of_additions_and_su...                 0.727273
# 0  final_solved_different,num_of_additions_and_su...                 0.800000
# 0  final_solved_different,num_of_additions_and_su...                 0.500000
# 0  final_solved_different,num_of_additions_and_su...                 1.000000
# 0  final_solved_different,num_of_additions_and_su...                 1.000000
# 0  final_solved_different,num_of_additions_and_su...                 1.000000
# 0  final_solved_different,num_of_additions_and_su...                 0.711207
# 0  final_solved_different,num_of_additions_and_su...                 0.715847
# 0  final_solved_different,num_of_additions_and_su...                 0.735714
# 0  final_solved_different,num_of_additions_and_su...                 0.732143
# 0  final_solved_different,num_of_additions_and_su...                 0.747126
# 0  final_solved_different,num_of_additions_and_su...                 0.803030
# 0  final_solved_different,num_of_additions_and_su...                 0.796296
# 0  final_solved_different,num_of_additions_and_su...                 0.800000
# 0  final_solved_different,num_of_additions_and_su...                 0.805556
# 0  final_solved_different,num_of_additions_and_su...                 0.777778
# 0  final_solved_different,num_of_additions_and_su...                 0.818182
# 0  final_solved_different,num_of_additions_and_su...                 0.750000
# 0  final_solved_different,num_of_additions_and_su...                 0.600000
# 0  final_solved_different,num_of_additions_and_su...                 0.666667
# 0  final_solved_different,num_of_additions_and_su...                 0.666667
# 0  final_solved_different,num_of_additions_and_su...                 1.000000
# 0                                                                    0.400402
# 0                                                                    0.399194
# 0  final_solved_different,num_of_additions_and_su...                 0.404412
# 0  final_solved_different,num_of_additions_and_su...                 0.411226
# 0  final_solved_different,num_of_additions_and_su...                 0.417952
# 0  final_solved_different,num_of_additions_and_su...                 0.405493
# 0  final_solved_different,num_of_additions_and_su...                 0.407045
# 0                                                                    0.387755
# 0  final_solved_different,num_of_additions_and_su...                 0.404762
# 0  final_solved_different,num_of_additions_and_su...                 0.440945
# 0  final_solved_different,num_of_additions_and_su...                 0.507937
# 0  final_solved_different,num_of_additions_and_su...                 0.555556
# 0  final_solved_different,num_of_additions_and_su...                 0.590909
# 0  final_solved_different,num_of_additions_and_su...                 0.571429
# 0  final_solved_different,num_of_additions_and_su...                 0.666667
# 0  final_solved_different,num_of_additions_and_su...                 1.000000
# 0  final_solved_different,num_of_additions_and_su...                 1.000000
# 0  final_solved_different,num_of_additions_and_su...                 1.000000
# 0  final_solved_different,num_of_additions_and_su...                 1.000000
# 0  final_solved_different,num_of_additions_and_su...                 1.000000
# 0  final_solved_different,num_of_additions_and_su...                 1.000000
# 0  final_solved_different,num_of_additions_and_su...                 1.000000
# 0  final_solved_different,num_of_additions_and_su...                 1.000000
# 0  final_solved_different,num_of_additions_and_su...                 1.000000
# 0  final_solved_different,num_of_additions_and_su...                 1.000000
# 0  final_solved_different,num_of_additions_and_su...                 1.000000
# 0  final_solved_different,num_of_additions_and_su...                 1.000000
# 0                                                                    0.397759
# 0  final_solved_different,num_of_additions_and_su...                 0.534483
# 0  final_solved_different,num_of_additions_and_su...                 0.614379
# 0  final_solved_different,num_of_additions_and_su...                 0.622222
# 0  final_solved_different,num_of_additions_and_su...                 0.571429
# 0  final_solved_different,num_of_additions_and_su...                 0.607143
# 0  final_solved_different,num_of_additions_and_su...                 0.647059
# 0  final_solved_different,num_of_additions_and_su...                 0.846154
# 0  final_solved_different,num_of_additions_and_su...                 1.000000
# 0  final_solved_different,num_of_additions_and_su...                 1.000000
# 0  final_solved_different,num_of_additions_and_su...                 1.000000
# 0  final_solved_different,num_of_additions_and_su...                 1.000000
# 0  final_solved_different,num_of_additions_and_su...                 1.000000
# 0  final_solved_different,num_of_additions_and_su...                 1.000000
# 0  final_solved_different,num_of_additions_and_su...                 1.000000
# 0  final_solved_different,num_of_additions_and_su...                 1.000000
# 0  final_solved_different,num_of_additions_and_su...                 1.000000
#
#    prior  conditional - prior
# 0  0.404             0.427461
# 0  0.404            -0.010154
# 0  0.404            -0.024155
# 0  0.404            -0.037508
# 0  0.404            -0.051416
# 0  0.404            -0.045953
# 0  0.404            -0.047777
# 0  0.404            -0.028277
# 0  0.404             0.007523
# 0  0.404             0.030483
# 0  0.404             0.061347
# 0  0.404             0.167429
# 0  0.404             0.262667
# 0  0.404             0.301882
# 0  0.404             0.336741
# 0  0.404             0.529333
# 0  0.404             0.496000
# 0  0.404             0.471000
# 0  0.404             0.429333
# 0  0.404             0.396000
# 0  0.404             0.596000
# 0  0.404             0.596000
# 0  0.404             0.596000
# 0  0.404             0.596000
# 0  0.404             0.596000
# 0  0.404             0.596000
# 0  0.404             0.596000
# 0  0.404             0.596000
# 0  0.404             0.596000
# 0  0.404             0.596000
# 0  0.404             0.596000
# 0  0.404             0.596000
# 0  0.404             0.596000
# 0  0.404             0.596000
# 0  0.404             0.596000
# 0  0.404             0.596000
# 0  0.404             0.596000
# 0  0.404             0.596000
# 0  0.404             0.596000
# 0  0.404             0.596000
# 0  0.404             0.596000
# 0  0.404             0.596000
# 0  0.404             0.596000
# 0  0.404             0.596000
# 0  0.404             0.596000
# 0  0.404             0.596000
# 0  0.404             0.596000
# 0  0.404             0.311356
# 0  0.404             0.340186
# 0  0.404             0.342988
# 0  0.404             0.332842
# 0  0.404             0.338574
# 0  0.404             0.362234
# 0  0.404             0.386323
# 0  0.404             0.399922
# 0  0.404             0.385474
# 0  0.404             0.370194
# 0  0.404             0.365231
# 0  0.404             0.318222
# 0  0.404             0.167429
# 0  0.404             0.196000
# 0  0.404             0.196000
# 0  0.404             0.346000
# 0  0.404             0.596000
# 0  0.404             0.329333
# 0  0.404             0.380314
# 0  0.404             0.336741
# 0  0.404             0.323273
# 0  0.404             0.396000
# 0  0.404             0.096000
# 0  0.404             0.596000
# 0  0.404             0.596000
# 0  0.404             0.596000
# 0  0.404             0.307207
# 0  0.404             0.311847
# 0  0.404             0.331714
# 0  0.404             0.328143
# 0  0.404             0.343126
# 0  0.404             0.399030
# 0  0.404             0.392296
# 0  0.404             0.396000
# 0  0.404             0.401556
# 0  0.404             0.373778
# 0  0.404             0.414182
# 0  0.404             0.346000
# 0  0.404             0.196000
# 0  0.404             0.262667
# 0  0.404             0.262667
# 0  0.404             0.596000
# 0  0.404            -0.003598
# 0  0.404            -0.004806
# 0  0.404             0.000412
# 0  0.404             0.007226
# 0  0.404             0.013952
# 0  0.404             0.001493
# 0  0.404             0.003045
# 0  0.404            -0.016245
# 0  0.404             0.000762
# 0  0.404             0.036945
# 0  0.404             0.103937
# 0  0.404             0.151556
# 0  0.404             0.186909
# 0  0.404             0.167429
# 0  0.404             0.262667
# 0  0.404             0.596000
# 0  0.404             0.596000
# 0  0.404             0.596000
# 0  0.404             0.596000
# 0  0.404             0.596000
# 0  0.404             0.596000
# 0  0.404             0.596000
# 0  0.404             0.596000
# 0  0.404             0.596000
# 0  0.404             0.596000
# 0  0.404             0.596000
# 0  0.404             0.596000
# 0  0.404            -0.006241
# 0  0.404             0.130483
# 0  0.404             0.210379
# 0  0.404             0.218222
# 0  0.404             0.167429
# 0  0.404             0.203143
# 0  0.404             0.243059
# 0  0.404             0.442154
# 0  0.404             0.596000
# 0  0.404             0.596000
# 0  0.404             0.596000
# 0  0.404             0.596000
# 0  0.404             0.596000
# 0  0.404             0.596000
# 0  0.404             0.596000
# 0  0.404             0.596000
# 0  0.404             0.596000

# %%
chatgpt_stats = {}
chatgpt_stats.update(some_correct={
    'count': features_df.apply(lambda row : 1 if row["normal_correct"] == 'some' else 0, axis=1).sum(),
    'definition': "ChatGPT's response  mentioned some of the numbers in the solution"
})
chatgpt_stats.update(all_correct={
    'count': features_df.apply(lambda row : 1 if row["normal_correct"] == 'all' else 0, axis=1).sum(),
    'definition': "ChatGPT's response mentioned all the numbers in the solution"
})
chatgpt_stats.update(some_correct_rounded={
    'count': features_df.apply(lambda row : 1 if row["rounded_correct"] == 'some' and row["normal_correct"] == 'none' else 0, axis=1).sum(),
    'definition':"ChatGPT's response mentioned some of the numbers in the solution when both answers and ChatGPT's solutions were rounded."
})

chatgpt_stats.update(all_correct_rounded={
    'count': features_df.apply(lambda row : 1 if row["rounded_correct"] == 'all'  and row["normal_correct"] == 'none' else 0, axis=1).sum(),
    'definition': "ChatGPT's response mentioned all the numbers in the solution when both answers and ChatGPT's solutions were rounded."
})

chatgpt_stats.update(none_correct={
    'count': features_df.apply(lambda row : 1 if row["normal_correct"] == 'none' and row["rounded_correct"] == 'none' else 0, axis=1).sum(),
    'definition': "ChatGPT's response did not mention any of the numbers in the solution."
})

# %%
from xlsx_creation.xlsx_writer import XlsxWriter
XlsxWriter.write_xlsx(stats_obj = chatgpt_stats,causality_df=causality_df, output_file_path=XLSX_OUTPUT_FILE_PATH, description="JSON", results_dict=results_dict, input_df=None)

# %%
CACHED = True
